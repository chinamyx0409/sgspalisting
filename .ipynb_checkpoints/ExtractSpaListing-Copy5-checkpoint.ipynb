# %%
import re
import requests
from bs4 import BeautifulSoup

# URL of the page to scrape
# url = 'https://g1298.com/category/west-area/'
url = 'https://g1298.com/category/central-area/'

# Send a request to the website
response = requests.get(url)

# Parse the HTML content of the page
soup = BeautifulSoup(response.content, 'html.parser')

# Find all articles in the West Area category
articles = soup.find_all('article', class_='category-central-area')


# Loop through each article and extract information
for article in articles:


    # Ensure there are enough classes in the list to avoid IndexError
    if len(article['class']) >7:
        region = article['class'][7]  # Access the 7th element in the list (index 6)
        print(f"region: {region}")
    else:
        print("Class list is too short.")

    
    # Extract the spa name
    spa_name = article.find('h2', class_='entry-title').get_text()

    # Extract the date
    # date = article.find('time', class_='entry-date').get_text()
    
    time_element = article.find('time', class_='entry-date')
    date = time_element.get_text()
    datetime = time_element['datetime']  # This extracts the full datetime string, e.g., "2023-11-02T08:46:59+08:00"


    # Extract the shop image source and dimensions
    shop_image_tag = article.find('div', class_='post-thumbnail').find('img')
    shop_image_src = shop_image_tag['src']
    shop_image_width = shop_image_tag['width']
    shop_image_height = shop_image_tag['height']



   # Find all staff images and extract their names from the alt attribute
    staff_images = article.find_all('img', alt=True)
    staff_names = [img['alt'] for img in staff_images if 'Therapist' in img['alt']]


    
    # Extract all staff images
    staff_images = article.find_all('figure', class_='wp-block-image')
    staff_info = []
    for img in staff_images:
        staff_image_src = img.find('img')['src']
        staff_image_width = img.find('img')['width']
        staff_image_height = img.find('img')['height']
        staff_image_alt = img.find('img')['alt']
        staff_info.append({
            'source': staff_image_src,
            'width': staff_image_width,
            'height': staff_image_height,
            'alt': staff_image_alt
        })

    # Extract the shop description
    description = article.find('h2', class_='wp-block-heading').get_text()


    # Extract the service description
    service_description = article.find('p', class_='has-text-align-center').get_text()

    
    # Using regular expression to find 'Opening Hours'
    #opening_hours_match = re.search(r'Opening Hours\s+\d{1,2}\.\d{2}am\s+to\s+\d{1,2}\.\d{2}pm', service_description)
    #opening_hours_match = re.search(r'Operating Hours\s+(\d{1,2}\.\d{2}am\s+to\s+\d{1,2}\.\d{2}pm)', service_description)
    opening_hours_match = re.search(r'Opening Hours\s*(\d{1,2}\.\d{2}am\s+to\s+\d{1,2}\.\d{2}(?:am|pm))', service_description, re.IGNORECASE)


    if opening_hours_match:
        opening_hours = opening_hours_match.group()
    else:
        opening_hours = "Not available"
    
    # Update service_description to exclude 'Opening Hours'
    service_description = service_description.replace(opening_hours, '').strip()


    
    # Find the a tag with href attribute starting with "tel:"
    contact_tag = article.find('a', href=re.compile(r'^tel:'))
    contact = contact_tag['href'][4:] if contact_tag else "Not available"  # Extracts the phone number part
    
    # Extract contact and WhatsApp information
    contact_info = service_description  # Assuming the contact info is in the same paragraph as the service description
    whatsapp_image = article.find('img', alt=True, src=True)  # Assuming the first image with alt and src is the WhatsApp icon
    whatsapp_link = whatsapp_image['src'] if whatsapp_image else None

    # Print or process the extracted information
    # Extract category

    print(f"url: {url}")
    print(f"Spa Name: {spa_name}")
    print(f"Date: {date}")
    print(f"DateTime published: {datetime}")
    print(f"Shop Image: {shop_image_src} ({shop_image_width} x {shop_image_height})")
#   print(f"Staff Names: {staff_names}")
#   print(f"Staff Images: {staff_info}")
    print(f"Description: {description}")
    print(f"Services: {service_description}")
    print(f"Opening Hours: {opening_hours}")
#   print(f"Contact: {contact_info}")
    print(f"Contact: {contact}")
    print(f"WhatsApp Link: {whatsapp_link}")
    print("------------------------------------------------------")
# Out:
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Seasons Wellness Spa 43 Beach Road
# Date: 20/11/2023
# DateTime published: 2023-11-20T12:46:19+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Seasons Wellness Spa located in 43 Beach Road By G1298.com – The Massage Directory
# Services: Massages to Restore the Harmony in Your Body.60min Body Massage $6890min Body Massage $98120min Body Massage $11643 Beach Road Singapore 189681
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: +65 6336 8105
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Ichiban The Spa 9 Selegie Road
# Date: 19/11/2023
# DateTime published: 2023-11-19T15:39:57+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Best Massage Spa in Singapore Ichiban The Spa located in 9 Selegie Road By G1298.com – The Massage Directory
# Services: 60min Swedish Massage $8460min Hot Oil Massage $8490min Swedish Massage $1269 Selegie Road, #01-31 Selegie House,Singapore 180009
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: 65 6333 3344
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: YuQuan Spa 288 Jalan Besar
# Date: 14/11/2023
# DateTime published: 2023-11-14T16:14:41+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: YuQuan Spa at Jalan Besar by G1298.com – The Massage Directory
# Services: 40mins Swedish Full Body Care $5060mins Chinese Therapy / Tuina $6090mins Chinese Therapy Full Body $88288 Jalan Besar #01-01 Feng Ming Building Singapore 208951
# Opening Hours: Opening Hours 10.00am to 2.00am
# Contact: 65 6539 9858
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Cuppage Wellness 5 Koek Road
# Date: 13/10/2023
# DateTime published: 2023-10-13T10:11:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Expert Massage Services for Pain Relief and Relaxation Cuppage Wellness By G1298.com – The Massage Directory
# Services: 60min Full Body Massage $5860min Hot Oil Full Body Massage $6860min Korean Bubble Foam Massage $865 Koek Road #B1-02 Cupppage Plaza Singapore 228796Operating Hours: 10.30am to 11.00pm
# Opening Hours: Not available
# Contact: +65 8267 5689
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: SPA M Blk 8 Telok Blangah Crescent
# Date: 30/08/2023
# DateTime published: 2023-08-30T13:20:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Find Inner Peace and Relaxation with Our Massage and Spa Treatments Spa M located in Telok BIangah Crescent by G1298.com – The Massage Directory
# Services: 60mins Deep Tissue Massage $5890mins Deep Tissue Massage $88120mins Deep Tissue Massage $118Blk 8 Telok BIangah Crescent #01-157 Singapore 090008
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: +65 6980 8479
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Soul Wellness Spa 41 Holland Drive
# Date: 29/08/2023
# DateTime published: 2023-08-29T11:26:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20299'%3E%3C/svg%3E (500 x 299)
# Description: Soul Wellness Spa today Conveniently located in the heart of Holland G1298.com – The Massage Directory
# Services: We provide the best customer service to our clients in our beloved Hoboken. Ample parking lots right behind our spa. 60mins Full Body Massage $8990mins Full Body Massage $12941 holland drive Singapore 270041Opening Hours: 9.00am to 10.30pm
# Opening Hours: Not available
# Contact: +65 6493 2656
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20299'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Sgyogamassage 333 Beach Road
# Date: 27/08/2023
# DateTime published: 2023-08-27T09:33:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Description: Sgyogamassage located in 333 Beach Road experience the traditional Chinese Full body Therapy.
# Services: Tuina is a hands-on body massage treatment that uses Chinese Medicine (TCM) principles60mins TCM Therapy / Tuina $58 90minsTCM Therapy / Tuina  $88333 Beach Road Singapore 199563
# Opening Hours: Opening Hours 10.30am to 10.30pm
# Contact: +65 6518 3305
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 14 Kim Keat lane
# Date: 24/08/2023
# DateTime published: 2023-08-24T10:34:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Description: Get the Ultimate Massage Experience at Bliss Paradise 14 Kim Keat Lane
# Services: 60mins Full Body Massage $6090mins Full Body Massage $9014 Kim Keat Lane Singapore 328872
# Opening Hours: Opening Hours 10.00am to 1.00am
# Contact: 65 6539 9858
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: TL Beauty Wellness 220 Orchard Road
# Date: 22/08/2023
# DateTime published: 2023-08-22T20:01:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: G1298.com – Your Premier Choice for Expert Massage Services TL Beauty Wellness located in Midpoint Orchard
# Services: 60min Full Body Massage $5860min Hot Oil Full Body Massage $6860min Korean Bubble Foam Massage $86220 Orchard Rd, #02-06 Midpoint Orchard, Singapore 238852Operating Hours: 10.30am to 10.30pm
# Opening Hours: Not available
# Contact: +65 8334 8801
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Almond Spa 150 South Bridge Road
# Date: 20/08/2023
# DateTime published: 2023-08-20T09:03:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Best Massage Spa in Singapore Almond Spa located in South Bridge Road by G1298.com – The Massage Directory
# Services: 60mins Chinese Massage $5890mins Chinese Massage $86120mins Chinese Massage $108150 South Bridge Road, 01-18, Fook Hai Building Singapore 058727We’re Hiring. Join Our Team
# Opening Hours: Opening Hours 10.00am to 10.30pm
# Contact: 65 6015 0769
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Wan Jia Wellness 279 Outram Road
# Date: 19/08/2023
# DateTime published: 2023-08-19T23:01:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Wan Jia Wellness: Experts in Stress Reduction and Pain Management By G1298.com – The Massage Directory
# Services: Each of our therapists have years of experience in massage therapy.60mins Chinese Massage $6090mins Chinese Massage $88279 Outram Road, #01-01 Outram Loft, Singapore 169066We’re Hiring. Join Our Team
# Opening Hours: Opening Hours 10.30am to 10.30pm
# Contact: +65 6993 7853
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 86 Circuit Road
# Date: 17/08/2023
# DateTime published: 2023-08-17T13:45:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Get the Ultimate Body Massage Experience at Bliss Paradise 86 Circuit Road By G1298.com – The Massage Directory
# Services: 60mins Full Body Massage $6090mins Full Body Massage $9086 Circuit Road #01-995 Singapore 370086
# Opening Hours: Opening Hours 10.30am to 1.00am
# Contact: 65 8188 1252
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Liu Xin Yu wellness & Spa 78 Guan Chuan Street
# Date: 16/08/2023
# DateTime published: 2023-08-16T11:00:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Liu Xin Yu Start your day feeling relaxed with our Happy hour promotion!
# Services: 9.00 am to 1.00pm60min Full Body Oriental Massage $5890min Full Body Oriental Massage $87BLK 78 Guan Chuan Street 01-45 Singapore 160078
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: 65 6525 9468
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Li Xin Beauty Wellness 30 Sago Street
# Date: 16/08/2023
# DateTime published: 2023-08-16T06:50:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Art of Massage Li Xin Beauty Wellness located in 30 Sago Street By G1298.com – The Massage Directory
# Services: 60min Full Body Oriental Massage $5890min Full Body Oriental Massage $8530 Sago Street, Singapore 059024
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: 65 6225 3231
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Ann Healthcare 221 Balestier Road
# Date: 14/08/2023
# DateTime published: 2023-08-14T11:23:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Ann Healthcare Centre located in Balestier Road Spa
# Services: Our therapists are both friendly and highly skilled, with years of experience providing expert services. Prostate Massage acupressure points around the groin can promote better blood flow to your body, benefiting your overall health.60mins Bodycare $6090mins Bodycare $90120mins Bodycare $120 60mins Prostate Massage $150Painless hair removal Price Range $50 – $350221 Balestier Road Singapore 329928We’re Hiring. Join Our Team
# Opening Hours: Opening Hours 9.30am to 10.30pm
# Contact: 65 8740 4888
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Yue Yuan Spa 805 North Bridge Road
# Date: 12/08/2023
# DateTime published: 2023-08-12T10:20:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Relax and Rejuvenate with our Expert Massage Services Yue Yuan Spa located in North Bridge Road.
# Services: Each of our therapists have years of experience.60mins Body Massage $6090mins Body Massage $90120mins Body Massage $120805 North Bridge Road Singapore 198773We’re Hiring. Join Our Team
# Opening Hours: Opening Hours 7.00am to 10.30pm
# Contact: +65 6298 2326
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 623 Balestier Road
# Date: 11/08/2023
# DateTime published: 2023-08-11T15:55:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20400'%3E%3C/svg%3E (500 x 400)
# Description: Experience Lasting Relief with Bliss Paradise 623 Balestier Road Your Go-To for Massage Therapy Near You
# Services: 60mins Full Body Massage $6090mins Full Body Massage $90623 Balestier Road Singapore 329914
# Opening Hours: Opening Hours 10.30am to 1.00am
# Contact: 65 8188 1252
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20400'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Palace Spa 116 Middle Road
# Date: 08/08/2023
# DateTime published: 2023-08-08T09:44:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Relax and Rejuvenate with Affordable Massage Services at Palace Spa, Bugis – $48/Hour
# Services: 60mins Chinese Massage $5590mins Chinese Massage $82116 Middle Road #02-01, ICB Enterprise House Singapore 188972Operating Hours: 8.30am to 10.30pmWe’re Hiring. Join Our Team
# Opening Hours: Not available
# Contact: 65 6970 2729
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 7 Tanjong Pagar Plaza
# Date: 06/08/2023
# DateTime published: 2023-08-06T09:19:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Description: Unlocking the Healing Power of TCM Massage Effective Techniques and Benefits at Bliss Paradise 7 Tanjong Pagar Plaza
# Services: 60mins Body Therapy $6090mins Body Therapy $90Blk 7 Tanjong Pagar Plaza #02-108 Singapore 081007
# Opening Hours: Opening Hours 11.00am to 1.00am
# Contact: 65 8188 1252
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Nature Spa 126 Owen Road
# Date: 05/08/2023
# DateTime published: 2023-08-05T08:05:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Discover Pure Relaxation Thai Massage Near Me at Nature Spa Owen Road
# Services: 60mins Thai & Oil Full Body Massage $6890mins Thai & Oil Full Body Massage $98126 Owen Road #01-01 Singapore 218930
# Opening Hours: Opening Hours 10.00am to 10.30pm
# Contact: 65 6908 2738
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Yi He Tang 134 Rangoon Road
# Date: 04/08/2023
# DateTime published: 2023-08-04T17:24:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: 益和堂 TCM Massage Near Me at Yi He Tang – Experience Traditional Healing By G1298.com – The Massage Directory
# Services: Our highly skilled therapists are trained in the art of TCM massage, ensuring an authentic and effective treatment.60mins Chinese therapy $6890mins Chinese therapy $98134 Rangoon Road Singapore 218412
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: +65 8556 9488
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 205 Syed Alwi Road
# Date: 02/08/2023
# DateTime published: 2023-08-02T09:34:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Bliss Paradise 205 Syed Alwi Road
# Services: Find Total Relaxation at Bliss ParadiseSingapore’s Best Massage for Stress and Tension Relief60mins Full Body Massage $6090mins Full Body Massage $90205 Syed Alwi Road, Singapore 207737
# Opening Hours: Opening Hours 12.00am to 3.00am
# Contact: 65 8188 1252
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Xuan Spa 438 Race Course Road
# Date: 29/07/2023
# DateTime published: 2023-07-29T11:41:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Xuan Spa located in 438 Race Course Road – Experience the Benefits of Massage Therapy for Relaxation and Healing
# Services: Promo price is only applicable between 9:30am-2pm daily60mins Hot Oil full body Massage $5890mins Hot Oil full body Massage $8690mins Hot Oil full body Massage $108438 Race Course Road Singapore 218684
# Opening Hours: Opening Hours 9.30am to 10.30pm
# Contact: +65 6294 9948
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Mu Wellness 332 Balestier Road
# Date: 24/07/2023
# DateTime published: 2023-07-24T20:09:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Unwind and Rejuvenate with Aromatherapy Massage at MU WELLNESS by G1298.com – The Massage Directory
# Services: 60min Full Body Massage $5890min Full Body Massage $80332 Balestier Road Singapore 329764
# Opening Hours: Opening Hours 10.30am to 10.30pm
# Contact: +65 9087 3182
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Hito Iki Spa BlK 35 Telok Blangah Rise
# Date: 19/07/2023
# DateTime published: 2023-07-19T09:59:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Best Massage and Spa Services at Hito Iki Spa located in Telok Blangah Rise By G1298.com – The Massage Directory
# Services: 60mins Full Body Massage TCM $6090mins Full Body Massage TCM $90BIK 35 Telok Blangah Rise #01-277 Singapore 090035We’re Hiring. Join Our Team
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: 65 6518 3558
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Yi Ren Fang 67A Queen Street
# Date: 18/07/2023
# DateTime published: 2023-07-18T19:43:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Yi Ren Fang located in Queen Street Experts in Stress Reduction and Pain Management by G1298.com – The Massage Directory
# Services: Each of our therapists have years of experience in massage therapy.60mins Full Body Oli Massage $6090mins Full Body Oli Massage $8067A Queen Street 2nd Floor Singapore 188546
# Opening Hours: Opening Hours 9.30am to 10.30pm
# Contact: +65 6966 1360
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Yi Kang TCM Ang Mo Kio Ave 6
# Date: 16/07/2023
# DateTime published: 2023-07-16T21:44:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Yi Kang TCM & Therapy Center located in Mo Kio Ave 6 – Your Source for Pain Relief
# Services: 60min Body therapy $6090min Body therapy $9060min Tendon prostate therapy + Oli $80Blk 715 Ang Mo Kio Ave 6 #01-4004Singapore 560715
# Opening Hours: Opening Hours 10.30am to 10.30am
# Contact: 65 6983 7988
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: E Spa Ang Mo Kio Ave 1
# Date: 16/07/2023
# DateTime published: 2023-07-16T20:43:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Pampering Bliss Awaits at E Spa located in Ang Mo Kio Ave 1 By G1298.com – The Massage Directory
# Services: Expert Massage Services by Our Caring Therapists60mins Full Body Oil Massage $5890mins Full Body Oil Massage $8560mins Japaness Bubble Massage $98Blk 226C Ang Mo Kio Ave 1＃01-651 Singapore 563226
# Opening Hours: Opening Hours 8.30am to 10.30pm
# Contact: 65 6266 6606
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: The Mandarin in Wellness Ang Mo Kio Ave 5
# Date: 13/07/2023
# DateTime published: 2023-07-13T11:09:30+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Unlock Wellness The Power of The Mandarin in Wellness for Vibrant Living
# Services: Experience Skilled Massage Therapy by Certified Therapist Miya for Muscle Tension Relief.60mins Hot Oil Full Body Massage $6890mins Hot Oil Full Body Massage $102Blk 151 Ang Mo Kio Ave 5, #01-3034, Singapore 560151Opening Hours 10.30.am to 10.30pm
# Opening Hours: Not available
# Contact: +65 8398 7190
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: BaiHe Spa Bishan Street 11
# Date: 05/04/2023
# DateTime published: 2023-04-05T01:36:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: BaiHe Spa Experienced therapists who are dedicated to providing personalized care and exceptional service.
# Services: 60mins Full Body Massage $5890mins Full Body Massage $86152 Bishan Street 11, #01-221 Singapore 570152
# Opening Hours: Opening Hours 9.30am to 10.30pm
# Contact: 65 6258 9897
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Deluxe Spa Block 36 Beo Crescent
# Date: 01/03/2023
# DateTime published: 2023-03-01T15:18:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Welcome to Best Deluxe Spa relax your muscles
# Services: All our therapist are all certified with accredited wellness certification and trained professionally ease muscle tensions and soothing massage therapy60mins Swedish Massage $58Block 36 Beo Crescent #01-49 Singapore 160036Opening Hours 10.30.am to 10.30pm
# Opening Hours: Not available
# Contact: +65 9460 5280
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Fu Zu Wellness Blk 125 Lorong 1 Toa Payoh
# Date: 20/02/2023
# DateTime published: 2023-02-20T20:24:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Benefits of Massage at Fu Zu Wellness By G1298.com – The Massage Directory
# Services: 60min Full Body Massage $5890min Full Body Massage $85Blk 125 Lorong 1 Toa Payoh #01-543Singapore 310125
# Opening Hours: Opening Hours 9.30am to 10.30pm
# Contact: +65 6677 7636
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Spa D Raviver 11 Jalan Bukit Merah
# Date: 19/02/2023
# DateTime published: 2023-02-19T18:23:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Spa D Raviver located in Jalan Bukit Merah – Nurturing Mind, Body, and Soul with Care
# Services: 60min Full Body Massage $5590min Full Body Massage $8511 Jalan Bukit Merah, Singapore 150011
# Opening Hours: Opening Hours 10.30am to 10.30pm
# Contact: +65 6278 9628
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Foreveryouspa 234 River Valley Road
# Date: 14/02/2023
# DateTime published: 2023-02-14T11:03:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: At Foreveryouspa, Our Skilled Massage Therapists Deliver Exceptional Customer Service for Spa Massages
# Services: Our professional, experienced massage Spa therapists are waiting to serve you in our spa.60mins Body Massage $6090mins Body Massage $88234 River Valley Road, Singapore 238292.Operating Hours: 10.00am to 10.30pm
# Opening Hours: Not available
# Contact: +65 6235 5308
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: ParkView Thai Wellness Spa Alexandra Central Mall
# Date: 09/02/2023
# DateTime published: 2023-02-09T06:08:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: ParkView Thai Wellness Spa Traditional Thai massage. by G1298.com – The Massage Directory
# Services: We offer a range of soothing, deeply relaxing tension busting massages which focus on areas of the body that often suffer most from stress.45mins Oil Massage $5060mins Oil Massage $5890mins Oil Massage $88321 Alexandra Road, Alexandra central #03-10 Singapore 159971Opening Hours 10am to 10.30pm
# Opening Hours: Not available
# Contact: +65 8316 8559
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Orient TCM Beauty 574 Ang Mo Kio
# Date: 11/01/2023
# DateTime published: 2023-01-11T12:56:37+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Relieve Pain with Expert TCM Treatment at Orient TCM Beauty – Acupuncture, Cupping, Moxibustion, Tuina and more
# Services: 60min TCM Full Body Massage $8990min TCM Full Body Massage $11990min TCM Full Body Massage $148574 Ang Mo Kio Ave 10,#01-1839 Singapore 560574
# Opening Hours: Opening Hours 8.00am to 10.30pm
# Contact: +65 6539 9973
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Foot King Spa 531 Upper Cross Street
# Date: 15/12/2022
# DateTime published: 2022-12-15T07:24:26+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Foot King Spa has everything you expect for a genuine comfort.
# Services: Professional therapists always offer service tailored to your health condition. we care more than provide the best Massage service. 60min Foot Reflexology $3960min Body Massage $55531 Upper Cross Street #01-02 Hong Lim Complex Singapore 050531
# Opening Hours: Opening Hours 10.30am to 10.30pm
# Contact: +65 8175 8465
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Nature Healing 177 Toa Payoh Central
# Date: 29/09/2022
# DateTime published: 2022-09-29T15:54:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: Nature Healing we treat not just your symptoms, but also the root cause of your pain issues.
# Services: We focus on TCM Tuina, Guasha & Cupping. TCM Tuina can stimulate acupoints and help muscle to overall muscle to improve blood circulation and whole body health.60mins Full Body Massage $6860mins Foot Massage $45177 Toa Payoh Central #01-152 Singapore 310177Operating Hours: 10.00am to 10.30pm
# Opening Hours: Not available
# Contact: 65 6814 8866
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Phoenix TCM 52 Telok Blangah Road
# Date: 27/08/2022
# DateTime published: 2022-08-27T06:28:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the healing power of Phoenix TCM located in Telok Blangah Road By G1298.com The Massage Directory
# Services: 60mins Swedish Massage $6090mins Hot Oil Massage $12860mins Yoga Stretching Massage $8952 Telok Blangah Rd, House #01-01, Singapore 098829
# Opening Hours: Opening Hours 10.00am to 10.30pm
# Contact: +65 6530 3839
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: LQ Foot Therapy Spa 41 Holland Drive
# Date: 01/05/2022
# DateTime published: 2022-05-01T09:27:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: LQ Foot Therapy Spa Unisex massage conveniently located near Holland Village that offers treatments to de-stress and unwind both your body and your mind.
# Services: We have rich experience in full body massage and foot reflexology. by G1298.com The Massage DirectoryPromotion (before 4pm Monday – Friday)30mins Foot Massage $2230mins Body Massage $28Opening Hours 10.00am to 1030pm41 Holland Drive #01-25 Singapore 270041
# Opening Hours: Not available
# Contact: 65 6970 5177
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Palace Therapy 25 Club Street
# Date: 02/04/2022
# DateTime published: 2022-04-02T15:07:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: Palace Therapy Indulge Yourself in a Luxurious Oriental Boutique Spa Experience at Affordable Rates
# Services: Treat them to a therapeutic session that recharges their soul and body, book a session with us today! 60mins Oriental Body Massage $68 Before 8pm25 Club Street Singapore 069412
# Opening Hours: Opening Hours 10.00am to 10.30pm
# Contact: 65 6767 6466
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Mango Spa 3 Greendale Avenue
# Date: 01/03/2022
# DateTime published: 2022-03-01T11:58:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: The founding philosophy of Mango Spa is to provide an escape from the hustle and bustle of urban life in Singapore.
# Services: Tucked away in a cozy nook off Bukit Timah Roa­­­d, surrounded by lush greenery in the quaint Greenwood dining enclave, our team of hand-picked therapists and friendly store manager strive to create an immensely relaxing and pampering spa experience, specially curated to your tastes.​ We look forward to seeing you soon! Sincerely, Mango Spa60mins Body Massage $6590mins Deep tissue massage $9890mins Hot stones massage $1463 Greendale Ave, Singapore 289498Operating Hours: 9.00am to 10.30pm
# Opening Hours: Not available
# Contact: +65 6835 0038
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E
# ------------------------------------------------------

# %%
import re
import requests
from bs4 import BeautifulSoup
    
    # URL of the page to scrape
    # url = 'https://g1298.com/category/west-area/'
url = 'https://g1298.com/category/central-area/'


try:
    # Send a request to the website
    response = requests.get(url)
    response.raise_for_status()  # This will raise an HTTPError if the HTTP request returned an unsuccessful status code
   
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all articles in the West Area category
    articles = soup.find_all('article', class_='category-central-area')
    
    
    # Loop through each article and extract information
    for article in articles:
        try:
            # Ensure there are enough classes in the list to avoid IndexError
            if len(article['class']) >7:
                region = article['class'][7]  # Access the 7th element in the list (index 6)
                print(f"region: {region}")
            else:
                print("Class list is too short.")
        
            
            # Extract the spa name
            spa_name = article.find('h2', class_='entry-title').get_text()
        
            # Extract the date
            # date = article.find('time', class_='entry-date').get_text()
            
            time_element = article.find('time', class_='entry-date')
            date = time_element.get_text()
            datetime = time_element['datetime']  # This extracts the full datetime string, e.g., "2023-11-02T08:46:59+08:00"
        
        
            # Extract the shop image source and dimensions
            shop_image_tag = article.find('div', class_='post-thumbnail').find('img')
            shop_image_src = shop_image_tag['src']
            shop_image_width = shop_image_tag['width']
            shop_image_height = shop_image_tag['height']
    
        
           # Find all staff images and extract their names from the alt attribute
            staff_images = article.find_all('img', alt=True)
            staff_names = [img['alt'] for img in staff_images if 'Therapist' in img['alt']]
        
        
            
            # Extract all staff images
            staff_images = article.find_all('figure', class_='wp-block-image')
            staff_info = []
            for img in staff_images:
                staff_image_src = img.find('img')['src']
                staff_image_width = img.find('img')['width']
                staff_image_height = img.find('img')['height']
                staff_image_alt = img.find('img')['alt']
                staff_info.append({
                    'source': staff_image_src,
                    'width': staff_image_width,
                    'height': staff_image_height,
                    'alt': staff_image_alt
                })
        
            # Extract the shop description
            description = article.find('h2', class_='wp-block-heading').get_text()
        
        
            # Extract the service description
            service_description = article.find('p', class_='has-text-align-center').get_text()
        
            # Regular expression to capture either 'Opening Hours' or 'Operating Hours'
            opening_hours_match = re.search(r'(Opening|Operating) Hours:?\s*(\d{1,2}\.\d{2}(?:am|pm)\s+to\s+\d{1,2}\.\d{2}(?:am|pm))', service_description, re.IGNORECASE)
            
            if opening_hours_match:
                opening_hours = opening_hours_match.group(2)  # Group 2 contains the time portion
            else:
                opening_hours = "Not available"
        
            # Update service_description to exclude the matched hours text
            service_description = service_description.replace(opening_hours_match.group(0), '').strip() if opening_hours_match else service_description
        
        # Find the a tag with href attribute starting with "tel:"
        #    contact_tag = article.find('a', href=re.compile(r'^tel:'))
        #    contact = contact_tag['href'][4:] if contact_tag else "Not available"  # Extracts the phone number part
        
            # Find the a tag with href attribute starting with "tel:"
            contact_tag = article.find('a', href=re.compile(r'^tel:'))
            
            if contact_tag:
                contact = contact_tag.get_text(strip=True)  # Extracts the phone number text
                contact = contact_tag['href'][4:] if contact_tag else "Not available"  # Extracts the phone number part
                contact_format = {
                    "classes": " ".join(contact_tag.get('class', [])),  # Join all classes into a single string
                    "style": contact_tag.get('style', '')  # Get the style attribute
                }
            else:
                contact = "Not available"
                contact_format = {"classes": "", "style": ""}
          
            
            # Extract contact and WhatsApp information
            # Find the WhatsApp link and extract the phone number
            whatsapp_tag = article.find('a', href=re.compile(r'https://api.whatsapp.com/send\?phone='))
            if whatsapp_tag:
                whatsapp_contact = re.search(r'phone=(\d+)', whatsapp_tag['href']).group(1)
                whatsapp_img_tag = whatsapp_tag.find('img')
                whatsapp_format = {
                    "classes": " ".join(whatsapp_img_tag.get('class', [])),  # Join all classes into a single string
                    "style": whatsapp_img_tag.get('style', '')  # Get the style attribute
                }
            else:
                whatsapp_contact = "Not available"
                whatsapp_format = {"classes": "", "style": ""}
             
        
            # Print or process the extracted information
            # Extract category
        
            print(f"url: {url}")
            print(f"Spa Name: {spa_name}")
            print(f"Date: {date}")
            print(f"DateTime published: {datetime}")
            print(f"Shop Image: {shop_image_src} ({shop_image_width} x {shop_image_height})")
        #   print(f"Staff Names: {staff_names}")
        #   print(f"Staff Images: {staff_info}")
            print(f"Description: {description}")
            print(f"Services: {service_description}")
            print(f"Opening Hours: {opening_hours}")
            print(f"Contact: {contact}")
            print(f"Contact Format: {contact_format}")
            print(f"WhatsApp Contact: {whatsapp_contact}")
            print(f"WhatsApp Format: {whatsapp_format}")
            print("------------------------------------------------------")

        except Exception as e:
            print(f"An error occurred while processing an article: {e}")

except requests.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"An error occurred: {err}")
# Out:
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Seasons Wellness Spa 43 Beach Road
# Date: 20/11/2023
# DateTime published: 2023-11-20T12:46:19+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Seasons Wellness Spa located in 43 Beach Road By G1298.com – The Massage Directory
# Services: Massages to Restore the Harmony in Your Body.60min Body Massage $6890min Body Massage $98120min Body Massage $11643 Beach Road Singapore 189681
# Opening Hours: 9.00am to 10.30pm
# Contact: +65 6336 8105
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6594496956
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Ichiban The Spa 9 Selegie Road
# Date: 19/11/2023
# DateTime published: 2023-11-19T15:39:57+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Best Massage Spa in Singapore Ichiban The Spa located in 9 Selegie Road By G1298.com – The Massage Directory
# Services: 60min Swedish Massage $8460min Hot Oil Massage $8490min Swedish Massage $1269 Selegie Road, #01-31 Selegie House,Singapore 180009
# Opening Hours: 9.00am to 10.30pm
# Contact: 65 6333 3344
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6584243344
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'object-fit:cover;width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: YuQuan Spa 288 Jalan Besar
# Date: 14/11/2023
# DateTime published: 2023-11-14T16:14:41+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: YuQuan Spa at Jalan Besar by G1298.com – The Massage Directory
# Services: 40mins Swedish Full Body Care $5060mins Chinese Therapy / Tuina $6090mins Chinese Therapy Full Body $88288 Jalan Besar #01-01 Feng Ming Building Singapore 208951
# Opening Hours: 10.00am to 2.00am
# Contact: 65 6539 9858
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6593453568
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Cuppage Wellness 5 Koek Road
# Date: 13/10/2023
# DateTime published: 2023-10-13T10:11:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Expert Massage Services for Pain Relief and Relaxation Cuppage Wellness By G1298.com – The Massage Directory
# Services: 60min Full Body Massage $5860min Hot Oil Full Body Massage $6860min Korean Bubble Foam Massage $865 Koek Road #B1-02 Cupppage Plaza Singapore 228796
# Opening Hours: 10.30am to 11.00pm
# Contact: +65 8267 5689
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6582675689
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: SPA M Blk 8 Telok Blangah Crescent
# Date: 30/08/2023
# DateTime published: 2023-08-30T13:20:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Find Inner Peace and Relaxation with Our Massage and Spa Treatments Spa M located in Telok BIangah Crescent by G1298.com – The Massage Directory
# Services: 60mins Deep Tissue Massage $5890mins Deep Tissue Massage $88120mins Deep Tissue Massage $118Blk 8 Telok BIangah Crescent #01-157 Singapore 090008
# Opening Hours: 9.00am to 10.30pm
# Contact: +65 6980 8479
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6591803969
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Soul Wellness Spa 41 Holland Drive
# Date: 29/08/2023
# DateTime published: 2023-08-29T11:26:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20299'%3E%3C/svg%3E (500 x 299)
# Description: Soul Wellness Spa today Conveniently located in the heart of Holland G1298.com – The Massage Directory
# Services: We provide the best customer service to our clients in our beloved Hoboken. Ample parking lots right behind our spa. 60mins Full Body Massage $8990mins Full Body Massage $12941 holland drive Singapore 270041
# Opening Hours: 9.00am to 10.30pm
# Contact: +65 6493 2656
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6598598321
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Sgyogamassage 333 Beach Road
# Date: 27/08/2023
# DateTime published: 2023-08-27T09:33:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Description: Sgyogamassage located in 333 Beach Road experience the traditional Chinese Full body Therapy.
# Services: Tuina is a hands-on body massage treatment that uses Chinese Medicine (TCM) principles60mins TCM Therapy / Tuina $58 90minsTCM Therapy / Tuina  $88333 Beach Road Singapore 199563
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 6518 3305
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581970709
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 14 Kim Keat lane
# Date: 24/08/2023
# DateTime published: 2023-08-24T10:34:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Description: Get the Ultimate Massage Experience at Bliss Paradise 14 Kim Keat Lane
# Services: 60mins Full Body Massage $6090mins Full Body Massage $9014 Kim Keat Lane Singapore 328872
# Opening Hours: 10.00am to 1.00am
# Contact: 65 6539 9858
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581003642
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: TL Beauty Wellness 220 Orchard Road
# Date: 22/08/2023
# DateTime published: 2023-08-22T20:01:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: G1298.com – Your Premier Choice for Expert Massage Services TL Beauty Wellness located in Midpoint Orchard
# Services: 60min Full Body Massage $5860min Hot Oil Full Body Massage $6860min Korean Bubble Foam Massage $86220 Orchard Rd, #02-06 Midpoint Orchard, Singapore 238852
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 8334 8801
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6583348801
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Almond Spa 150 South Bridge Road
# Date: 20/08/2023
# DateTime published: 2023-08-20T09:03:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Best Massage Spa in Singapore Almond Spa located in South Bridge Road by G1298.com – The Massage Directory
# Services: 60mins Chinese Massage $5890mins Chinese Massage $86120mins Chinese Massage $108150 South Bridge Road, 01-18, Fook Hai Building Singapore 058727We’re Hiring. Join Our Team
# Opening Hours: 10.00am to 10.30pm
# Contact: 65 6015 0769
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6589026542
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Wan Jia Wellness 279 Outram Road
# Date: 19/08/2023
# DateTime published: 2023-08-19T23:01:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Wan Jia Wellness: Experts in Stress Reduction and Pain Management By G1298.com – The Massage Directory
# Services: Each of our therapists have years of experience in massage therapy.60mins Chinese Massage $6090mins Chinese Massage $88279 Outram Road, #01-01 Outram Loft, Singapore 169066We’re Hiring. Join Our Team
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 6993 7853
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6586180666
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 86 Circuit Road
# Date: 17/08/2023
# DateTime published: 2023-08-17T13:45:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Get the Ultimate Body Massage Experience at Bliss Paradise 86 Circuit Road By G1298.com – The Massage Directory
# Services: 60mins Full Body Massage $6090mins Full Body Massage $9086 Circuit Road #01-995 Singapore 370086
# Opening Hours: 10.30am to 1.00am
# Contact: 65 8188 1252
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581881252
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Liu Xin Yu wellness & Spa 78 Guan Chuan Street
# Date: 16/08/2023
# DateTime published: 2023-08-16T11:00:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Liu Xin Yu Start your day feeling relaxed with our Happy hour promotion!
# Services: 9.00 am to 1.00pm60min Full Body Oriental Massage $5890min Full Body Oriental Massage $87BLK 78 Guan Chuan Street 01-45 Singapore 160078
# Opening Hours: 9.00am to 10.30pm
# Contact: 65 6525 9468
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6585188949
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Li Xin Beauty Wellness 30 Sago Street
# Date: 16/08/2023
# DateTime published: 2023-08-16T06:50:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Art of Massage Li Xin Beauty Wellness located in 30 Sago Street By G1298.com – The Massage Directory
# Services: 60min Full Body Oriental Massage $5890min Full Body Oriental Massage $8530 Sago Street, Singapore 059024
# Opening Hours: 9.00am to 10.30pm
# Contact: 65 6225 3231
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6591121766
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'object-fit:cover;width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Ann Healthcare 221 Balestier Road
# Date: 14/08/2023
# DateTime published: 2023-08-14T11:23:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Ann Healthcare Centre located in Balestier Road Spa
# Services: Our therapists are both friendly and highly skilled, with years of experience providing expert services. Prostate Massage acupressure points around the groin can promote better blood flow to your body, benefiting your overall health.60mins Bodycare $6090mins Bodycare $90120mins Bodycare $120 60mins Prostate Massage $150Painless hair removal Price Range $50 – $350221 Balestier Road Singapore 329928We’re Hiring. Join Our Team
# Opening Hours: 9.30am to 10.30pm
# Contact: 65 8740 4888
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6587404888
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Yue Yuan Spa 805 North Bridge Road
# Date: 12/08/2023
# DateTime published: 2023-08-12T10:20:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Relax and Rejuvenate with our Expert Massage Services Yue Yuan Spa located in North Bridge Road.
# Services: Each of our therapists have years of experience.60mins Body Massage $6090mins Body Massage $90120mins Body Massage $120805 North Bridge Road Singapore 198773We’re Hiring. Join Our Team
# Opening Hours: 7.00am to 10.30pm
# Contact: +65 6298 2326
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6582834576
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 623 Balestier Road
# Date: 11/08/2023
# DateTime published: 2023-08-11T15:55:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20400'%3E%3C/svg%3E (500 x 400)
# Description: Experience Lasting Relief with Bliss Paradise 623 Balestier Road Your Go-To for Massage Therapy Near You
# Services: 60mins Full Body Massage $6090mins Full Body Massage $90623 Balestier Road Singapore 329914
# Opening Hours: 10.30am to 1.00am
# Contact: 65 8188 1252
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581881252
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Palace Spa 116 Middle Road
# Date: 08/08/2023
# DateTime published: 2023-08-08T09:44:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Relax and Rejuvenate with Affordable Massage Services at Palace Spa, Bugis – $48/Hour
# Services: 60mins Chinese Massage $5590mins Chinese Massage $82116 Middle Road #02-01, ICB Enterprise House Singapore 188972We’re Hiring. Join Our Team
# Opening Hours: 8.30am to 10.30pm
# Contact: 65 6970 2729
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6588762722
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 7 Tanjong Pagar Plaza
# Date: 06/08/2023
# DateTime published: 2023-08-06T09:19:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Description: Unlocking the Healing Power of TCM Massage Effective Techniques and Benefits at Bliss Paradise 7 Tanjong Pagar Plaza
# Services: 60mins Body Therapy $6090mins Body Therapy $90Blk 7 Tanjong Pagar Plaza #02-108 Singapore 081007
# Opening Hours: 11.00am to 1.00am
# Contact: 65 8188 1252
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581881252
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Nature Spa 126 Owen Road
# Date: 05/08/2023
# DateTime published: 2023-08-05T08:05:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Discover Pure Relaxation Thai Massage Near Me at Nature Spa Owen Road
# Services: 60mins Thai & Oil Full Body Massage $6890mins Thai & Oil Full Body Massage $98126 Owen Road #01-01 Singapore 218930
# Opening Hours: 10.00am to 10.30pm
# Contact: 65 6908 2738
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6590399878
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Yi He Tang 134 Rangoon Road
# Date: 04/08/2023
# DateTime published: 2023-08-04T17:24:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: 益和堂 TCM Massage Near Me at Yi He Tang – Experience Traditional Healing By G1298.com – The Massage Directory
# Services: Our highly skilled therapists are trained in the art of TCM massage, ensuring an authentic and effective treatment.60mins Chinese therapy $6890mins Chinese therapy $98134 Rangoon Road Singapore 218412
# Opening Hours: 9.00am to 10.30pm
# Contact: +65 8556 9488
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6585459319
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 205 Syed Alwi Road
# Date: 02/08/2023
# DateTime published: 2023-08-02T09:34:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Bliss Paradise 205 Syed Alwi Road
# Services: Find Total Relaxation at Bliss ParadiseSingapore’s Best Massage for Stress and Tension Relief60mins Full Body Massage $6090mins Full Body Massage $90205 Syed Alwi Road, Singapore 207737
# Opening Hours: 12.00am to 3.00am
# Contact: 65 8188 1252
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581881252
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Xuan Spa 438 Race Course Road
# Date: 29/07/2023
# DateTime published: 2023-07-29T11:41:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Xuan Spa located in 438 Race Course Road – Experience the Benefits of Massage Therapy for Relaxation and Healing
# Services: Promo price is only applicable between 9:30am-2pm daily60mins Hot Oil full body Massage $5890mins Hot Oil full body Massage $8690mins Hot Oil full body Massage $108438 Race Course Road Singapore 218684
# Opening Hours: 9.30am to 10.30pm
# Contact: +65 6294 9948
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6597793468
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Mu Wellness 332 Balestier Road
# Date: 24/07/2023
# DateTime published: 2023-07-24T20:09:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Unwind and Rejuvenate with Aromatherapy Massage at MU WELLNESS by G1298.com – The Massage Directory
# Services: 60min Full Body Massage $5890min Full Body Massage $80332 Balestier Road Singapore 329764
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 9087 3182
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6590873182
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Hito Iki Spa BlK 35 Telok Blangah Rise
# Date: 19/07/2023
# DateTime published: 2023-07-19T09:59:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Best Massage and Spa Services at Hito Iki Spa located in Telok Blangah Rise By G1298.com – The Massage Directory
# Services: 60mins Full Body Massage TCM $6090mins Full Body Massage TCM $90BIK 35 Telok Blangah Rise #01-277 Singapore 090035We’re Hiring. Join Our Team
# Opening Hours: 9.00am to 10.30pm
# Contact: 65 6518 3558
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6596422301
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Yi Ren Fang 67A Queen Street
# Date: 18/07/2023
# DateTime published: 2023-07-18T19:43:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Yi Ren Fang located in Queen Street Experts in Stress Reduction and Pain Management by G1298.com – The Massage Directory
# Services: Each of our therapists have years of experience in massage therapy.60mins Full Body Oli Massage $6090mins Full Body Oli Massage $8067A Queen Street 2nd Floor Singapore 188546
# Opening Hours: 9.30am to 10.30pm
# Contact: +65 6966 1360
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6588590954
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Yi Kang TCM Ang Mo Kio Ave 6
# Date: 16/07/2023
# DateTime published: 2023-07-16T21:44:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Yi Kang TCM & Therapy Center located in Mo Kio Ave 6 – Your Source for Pain Relief
# Services: 60min Body therapy $6090min Body therapy $9060min Tendon prostate therapy + Oli $80Blk 715 Ang Mo Kio Ave 6 #01-4004Singapore 560715
# Opening Hours: 10.30am to 10.30am
# Contact: 65 6983 7988
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6587384227
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: E Spa Ang Mo Kio Ave 1
# Date: 16/07/2023
# DateTime published: 2023-07-16T20:43:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Pampering Bliss Awaits at E Spa located in Ang Mo Kio Ave 1 By G1298.com – The Massage Directory
# Services: Expert Massage Services by Our Caring Therapists60mins Full Body Oil Massage $5890mins Full Body Oil Massage $8560mins Japaness Bubble Massage $98Blk 226C Ang Mo Kio Ave 1＃01-651 Singapore 563226
# Opening Hours: 8.30am to 10.30pm
# Contact: 65 6266 6606
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581293933
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: The Mandarin in Wellness Ang Mo Kio Ave 5
# Date: 13/07/2023
# DateTime published: 2023-07-13T11:09:30+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Unlock Wellness The Power of The Mandarin in Wellness for Vibrant Living
# Services: Experience Skilled Massage Therapy by Certified Therapist Miya for Muscle Tension Relief.60mins Hot Oil Full Body Massage $6890mins Hot Oil Full Body Massage $102Blk 151 Ang Mo Kio Ave 5, #01-3034, Singapore 560151Opening Hours 10.30.am to 10.30pm
# Opening Hours: Not available
# Contact: +65 8398 7190
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6583987190
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': ''}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: BaiHe Spa Bishan Street 11
# Date: 05/04/2023
# DateTime published: 2023-04-05T01:36:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: BaiHe Spa Experienced therapists who are dedicated to providing personalized care and exceptional service.
# Services: 60mins Full Body Massage $5890mins Full Body Massage $86152 Bishan Street 11, #01-221 Singapore 570152
# Opening Hours: 9.30am to 10.30pm
# Contact: 65 6258 9897
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6562589897
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': ''}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Deluxe Spa Block 36 Beo Crescent
# Date: 01/03/2023
# DateTime published: 2023-03-01T15:18:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Welcome to Best Deluxe Spa relax your muscles
# Services: All our therapist are all certified with accredited wellness certification and trained professionally ease muscle tensions and soothing massage therapy60mins Swedish Massage $58Block 36 Beo Crescent #01-49 Singapore 160036Opening Hours 10.30.am to 10.30pm
# Opening Hours: Not available
# Contact: +65 9460 5280
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6594605280
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': ''}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Fu Zu Wellness Blk 125 Lorong 1 Toa Payoh
# Date: 20/02/2023
# DateTime published: 2023-02-20T20:24:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Benefits of Massage at Fu Zu Wellness By G1298.com – The Massage Directory
# Services: 60min Full Body Massage $5890min Full Body Massage $85Blk 125 Lorong 1 Toa Payoh #01-543Singapore 310125
# Opening Hours: 9.30am to 10.30pm
# Contact: +65 6677 7636
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6589311378
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Spa D Raviver 11 Jalan Bukit Merah
# Date: 19/02/2023
# DateTime published: 2023-02-19T18:23:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Spa D Raviver located in Jalan Bukit Merah – Nurturing Mind, Body, and Soul with Care
# Services: 60min Full Body Massage $5590min Full Body Massage $8511 Jalan Bukit Merah, Singapore 150011
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 6278 9628
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6598432902
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Foreveryouspa 234 River Valley Road
# Date: 14/02/2023
# DateTime published: 2023-02-14T11:03:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: At Foreveryouspa, Our Skilled Massage Therapists Deliver Exceptional Customer Service for Spa Massages
# Services: Our professional, experienced massage Spa therapists are waiting to serve you in our spa.60mins Body Massage $6090mins Body Massage $88234 River Valley Road, Singapore 238292.
# Opening Hours: 10.00am to 10.30pm
# Contact: +65 6235 5308
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: ParkView Thai Wellness Spa Alexandra Central Mall
# Date: 09/02/2023
# DateTime published: 2023-02-09T06:08:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: ParkView Thai Wellness Spa Traditional Thai massage. by G1298.com – The Massage Directory
# Services: We offer a range of soothing, deeply relaxing tension busting massages which focus on areas of the body that often suffer most from stress.45mins Oil Massage $5060mins Oil Massage $5890mins Oil Massage $88321 Alexandra Road, Alexandra central #03-10 Singapore 159971Opening Hours 10am to 10.30pm
# Opening Hours: Not available
# Contact: +65 8316 8559
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6583168559
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Orient TCM Beauty 574 Ang Mo Kio
# Date: 11/01/2023
# DateTime published: 2023-01-11T12:56:37+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Relieve Pain with Expert TCM Treatment at Orient TCM Beauty – Acupuncture, Cupping, Moxibustion, Tuina and more
# Services: 60min TCM Full Body Massage $8990min TCM Full Body Massage $11990min TCM Full Body Massage $148574 Ang Mo Kio Ave 10,#01-1839 Singapore 560574
# Opening Hours: 8.00am to 10.30pm
# Contact: +65 6539 9973
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Foot King Spa 531 Upper Cross Street
# Date: 15/12/2022
# DateTime published: 2022-12-15T07:24:26+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Foot King Spa has everything you expect for a genuine comfort.
# Services: Professional therapists always offer service tailored to your health condition. we care more than provide the best Massage service. 60min Foot Reflexology $3960min Body Massage $55531 Upper Cross Street #01-02 Hong Lim Complex Singapore 050531
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 8175 8465
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Nature Healing 177 Toa Payoh Central
# Date: 29/09/2022
# DateTime published: 2022-09-29T15:54:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: Nature Healing we treat not just your symptoms, but also the root cause of your pain issues.
# Services: We focus on TCM Tuina, Guasha & Cupping. TCM Tuina can stimulate acupoints and help muscle to overall muscle to improve blood circulation and whole body health.60mins Full Body Massage $6860mins Foot Massage $45177 Toa Payoh Central #01-152 Singapore 310177
# Opening Hours: 10.00am to 10.30pm
# Contact: 65 6814 8866
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background', 'style': 'border-radius:10px'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Phoenix TCM 52 Telok Blangah Road
# Date: 27/08/2022
# DateTime published: 2022-08-27T06:28:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the healing power of Phoenix TCM located in Telok Blangah Road By G1298.com The Massage Directory
# Services: 60mins Swedish Massage $6090mins Hot Oil Massage $12860mins Yoga Stretching Massage $8952 Telok Blangah Rd, House #01-01, Singapore 098829
# Opening Hours: 10.00am to 10.30pm
# Contact: +65 6530 3839
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6584385168
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: LQ Foot Therapy Spa 41 Holland Drive
# Date: 01/05/2022
# DateTime published: 2022-05-01T09:27:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: LQ Foot Therapy Spa Unisex massage conveniently located near Holland Village that offers treatments to de-stress and unwind both your body and your mind.
# Services: We have rich experience in full body massage and foot reflexology. by G1298.com The Massage DirectoryPromotion (before 4pm Monday – Friday)30mins Foot Massage $2230mins Body Massage $28Opening Hours 10.00am to 1030pm41 Holland Drive #01-25 Singapore 270041
# Opening Hours: Not available
# Contact: 65 6970 5177
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background', 'style': 'border-radius:10px'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Palace Therapy 25 Club Street
# Date: 02/04/2022
# DateTime published: 2022-04-02T15:07:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: Palace Therapy Indulge Yourself in a Luxurious Oriental Boutique Spa Experience at Affordable Rates
# Services: Treat them to a therapeutic session that recharges their soul and body, book a session with us today! 60mins Oriental Body Massage $68 Before 8pm25 Club Street Singapore 069412
# Opening Hours: 10.00am to 10.30pm
# Contact: 65 6767 6466
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# region: category-central-area
# url: https://g1298.com/category/central-area/
# Spa Name: Mango Spa 3 Greendale Avenue
# Date: 01/03/2022
# DateTime published: 2022-03-01T11:58:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: The founding philosophy of Mango Spa is to provide an escape from the hustle and bustle of urban life in Singapore.
# Services: Tucked away in a cozy nook off Bukit Timah Roa­­­d, surrounded by lush greenery in the quaint Greenwood dining enclave, our team of hand-picked therapists and friendly store manager strive to create an immensely relaxing and pampering spa experience, specially curated to your tastes.​ We look forward to seeing you soon! Sincerely, Mango Spa60mins Body Massage $6590mins Deep tissue massage $9890mins Hot stones massage $1463 Greendale Ave, Singapore 289498
# Opening Hours: 9.00am to 10.30pm
# Contact: +65 6835 0038
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background', 'style': 'border-radius:10px'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------

# %%
import re
import requests
from bs4 import BeautifulSoup

# URL of the page to scrape
url = 'https://g1298.com/category/central-area/'


# Function to clean the services description
def clean_services(services, words_to_remove):
    cleaned_services = []
    for service in services:
        for word in words_to_remove:
            service = re.sub(r'\b{}\b'.format(re.escape(word)), '', service, flags=re.IGNORECASE)
        cleaned_services.append(service.strip())
    return ', '.join(cleaned_services).replace(' ,', ',').strip()



try:
    # Send a request to the website
    response = requests.get(url)
    response.raise_for_status()  # Raises an HTTPError for unsuccessful status codes

    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all articles in the Central Area category
    articles = soup.find_all('article', class_='category-central-area')

    # Loop through each article and extract information
    for article in articles:
        try:
            # Extract the spa name
            spa_name = article.find('h2', class_='entry-title').get_text()

            # Extract the date and datetime
            time_element = article.find('time', class_='entry-date')
            date = time_element.get_text()
            datetime = time_element['datetime']

            # Extract the shop image source and dimensions
            shop_image_tag = article.find('div', class_='post-thumbnail').find('img')
            shop_image_src = shop_image_tag['src']
            shop_image_width = shop_image_tag['width']
            shop_image_height = shop_image_tag['height']

            # Extract the shop description
            description = article.find('h2', class_='wp-block-heading').get_text()

            # Extract the service description
            service_description = article.find('p', class_='has-text-align-center').get_text()

            # Regular expression to capture 'Opening Hours' or 'Operating Hours'
            opening_hours_match = re.search(r'(Opening|Operating) Hours:?\s*(\d{1,2}\.\d{2}(?:am|pm)\s+to\s+\d{1,2}\.\d{2}(?:am|pm))', service_description, re.IGNORECASE)
            opening_hours = opening_hours_match.group(2) if opening_hours_match else "Not available"
            service_description = service_description.replace(opening_hours_match.group(0), '').strip() if opening_hours_match else service_description

            # Extract contact information
            contact_tag = article.find('a', href=re.compile(r'^tel:'))
            if contact_tag:
                contact = contact_tag['href'][4:]  # Extracts the phone number
                contact_format = {
                    "classes": " ".join(contact_tag.get('class', [])),
                    "style": contact_tag.get('style', '')
                }
            else:
                contact = "Not available"
                contact_format = {"classes": "", "style": ""}

            # Extract WhatsApp contact information
            whatsapp_tag = article.find('a', href=re.compile(r'https://api.whatsapp.com/send\?phone='))
            if whatsapp_tag:
                whatsapp_contact = re.search(r'phone=(\d+)', whatsapp_tag['href']).group(1)
                whatsapp_img_tag = whatsapp_tag.find('img')
                whatsapp_format = {
                    "classes": " ".join(whatsapp_img_tag.get('class', [])),
                    "style": whatsapp_img_tag.get('style', '')
                }
            else:
                whatsapp_contact = "Not available"
                whatsapp_format = {"classes": "", "style": ""}

 
            # Extract the spa name
            spa_name = article.find('h2', class_='entry-title').get_text()

            # Extract the service description
            service_element = article.find('p', class_='has-text-align-center')
            services_lines = service_element.get_text(separator='\n').split('\n')

            # Identify the line containing the location
            location = "Not available"
            services = []
            for line in services_lines:
                if 'Singapore' in line:
                    location = line
                elif 'Opening Hours' not in line:
                    services.append(line)

            # Prepare words to be removed from services
            words_to_remove = set(re.findall(r'\b\w+\b', spa_name + ' ' + location))

            # Clean the services description
            service_description = clean_services(services, words_to_remove)

            
            # Print the extracted information
            print(f"url: {url}")
            print(f"Spa Name: {spa_name}")
            print(f"Date: {date}")
            print(f"DateTime published: {datetime}")
            print(f"Shop Image: {shop_image_src} ({shop_image_width} x {shop_image_height})")


            print(f"Spa Name: {spa_name}")
            print(f"Location: {location}")
            print(f"Services: {service_description}")
            
            #print(f"Description: {description}")
           
            print(f"Opening Hours: {opening_hours}")
            print(f"Contact: {contact}")
            print(f"Contact Format: {contact_format}")
            print(f"WhatsApp Contact: {whatsapp_contact}")
            print(f"WhatsApp Format: {whatsapp_format}")
            print("------------------------------------------------------")

        except Exception as e:
            print(f"An error occurred while processing an article: {e}")

except requests.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"An error occurred: {err}")
# Out:
# url: https://g1298.com/category/central-area/
# Spa Name: Seasons Wellness Spa 43 Beach Road
# Date: 20/11/2023
# DateTime published: 2023-11-20T12:46:19+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Seasons Wellness Spa 43 Beach Road
# Location: 43 Beach Road Singapore 189681
# Services: Massages, to Restore the Harmony in Your Body., 60min Body Massage $68, 90min Body Massage $98, 120min Body Massage $116
# Opening Hours: 9.00am to 10.30pm
# Contact: +65 6336 8105
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6594496956
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Ichiban The Spa 9 Selegie Road
# Date: 19/11/2023
# DateTime published: 2023-11-19T15:39:57+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Ichiban The Spa 9 Selegie Road
# Location: Singapore 180009
# Services: 60min Swedish Massage $84, 60min Hot Oil Massage $84, 90min Swedish Massage $126,, #01-31  House,
# Opening Hours: 9.00am to 10.30pm
# Contact: 65 6333 3344
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6584243344
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'object-fit:cover;width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: YuQuan Spa 288 Jalan Besar
# Date: 14/11/2023
# DateTime published: 2023-11-14T16:14:41+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: YuQuan Spa 288 Jalan Besar
# Location: Singapore 208951
# Services: 40mins Swedish Full Body Care $50, 60mins Chinese Therapy / Tuina $60, 90mins Chinese Therapy Full Body $88, #01-01 Feng Ming Building
# Opening Hours: 10.00am to 2.00am
# Contact: 65 6539 9858
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6593453568
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Cuppage Wellness 5 Koek Road
# Date: 13/10/2023
# DateTime published: 2023-10-13T10:11:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Cuppage Wellness 5 Koek Road
# Location: Cupppage Plaza Singapore 228796
# Services: 60min Full Body Massage $58, 60min Hot Oil Full Body Massage $68, 60min Korean Bubble Foam Massage $86, #B1-02, Operating Hours: 10.30am to 11.00pm
# Opening Hours: 10.30am to 11.00pm
# Contact: +65 8267 5689
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6582675689
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: SPA M Blk 8 Telok Blangah Crescent
# Date: 30/08/2023
# DateTime published: 2023-08-30T13:20:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: SPA M Blk 8 Telok Blangah Crescent
# Location: Singapore 090008
# Services: 60mins Deep Tissue Massage $58, 90mins Deep Tissue Massage $88, 120mins Deep Tissue Massage $118, BIangah  #01-157
# Opening Hours: 9.00am to 10.30pm
# Contact: +65 6980 8479
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6591803969
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Soul Wellness Spa 41 Holland Drive
# Date: 29/08/2023
# DateTime published: 2023-08-29T11:26:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20299'%3E%3C/svg%3E (500 x 299)
# Spa Name: Soul Wellness Spa 41 Holland Drive
# Location: 41 holland drive Singapore 270041
# Services: We provide the best customer service to our clients in our beloved Hoboken. Ample parking lots right behind our ., 60mins Full Body Massage $89, 90mins Full Body Massage $129
# Opening Hours: 9.00am to 10.30pm
# Contact: +65 6493 2656
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6598598321
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Sgyogamassage 333 Beach Road
# Date: 27/08/2023
# DateTime published: 2023-08-27T09:33:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Spa Name: Sgyogamassage 333 Beach Road
# Location: 333 Beach Road Singapore 199563
# Services: Tuina is a hands-on body massage treatment that uses Chinese Medicine (TCM) principles, 60mins TCM Therapy / Tuina $58, 90minsTCM Therapy / Tuina  $88
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 6518 3305
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581970709
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 14 Kim Keat lane
# Date: 24/08/2023
# DateTime published: 2023-08-24T10:34:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Spa Name: Bliss Paradise 14 Kim Keat lane
# Location: 14 Kim Keat Lane Singapore 328872
# Services: 60mins Full Body Massage $60, 90mins Full Body Massage $90
# Opening Hours: 10.00am to 1.00am
# Contact: 65 6539 9858
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581003642
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: TL Beauty Wellness 220 Orchard Road
# Date: 22/08/2023
# DateTime published: 2023-08-22T20:01:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: TL Beauty Wellness 220 Orchard Road
# Location: Singapore 238852
# Services: 60min Full Body Massage $58, 60min Hot Oil Full Body Massage $68, 60min Korean Bubble Foam Massage $86, Rd, #02-06 Midpoint,, Operating Hours: 10.30am to 10.30pm
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 8334 8801
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6583348801
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Almond Spa 150 South Bridge Road
# Date: 20/08/2023
# DateTime published: 2023-08-20T09:03:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Almond Spa 150 South Bridge Road
# Location: Fook Hai Building Singapore 058727
# Services: 60mins Chinese Massage $58, 90mins Chinese Massage $86, 120mins Chinese Massage $108,, 01-18,, We’re Hiring. Join Our Team
# Opening Hours: 10.00am to 10.30pm
# Contact: 65 6015 0769
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6589026542
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Wan Jia Wellness 279 Outram Road
# Date: 19/08/2023
# DateTime published: 2023-08-19T23:01:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Wan Jia Wellness 279 Outram Road
# Location: Singapore 169066
# Services: Each of our therapists have years of experience in massage therapy., 60mins Chinese Massage $60, 90mins Chinese Massage $88,, #01-01  Loft,, We’re Hiring. Join Our Team
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 6993 7853
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6586180666
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 86 Circuit Road
# Date: 17/08/2023
# DateTime published: 2023-08-17T13:45:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Bliss Paradise 86 Circuit Road
# Location: 86 Circuit Road #01-995 Singapore 370086
# Services: 60mins Full Body Massage $60, 90mins Full Body Massage $90
# Opening Hours: 10.30am to 1.00am
# Contact: 65 8188 1252
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581881252
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Liu Xin Yu wellness & Spa 78 Guan Chuan Street
# Date: 16/08/2023
# DateTime published: 2023-08-16T11:00:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Liu Xin Yu wellness & Spa 78 Guan Chuan Street
# Location: Singapore 160078
# Services: 9.00 am to 1.00pm, 60min Full Body Oriental Massage $58, 90min Full Body Oriental Massage $87, BLK     01-45
# Opening Hours: 9.00am to 10.30pm
# Contact: 65 6525 9468
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6585188949
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Li Xin Beauty Wellness 30 Sago Street
# Date: 16/08/2023
# DateTime published: 2023-08-16T06:50:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Li Xin Beauty Wellness 30 Sago Street
# Location: 30 Sago Street, Singapore 059024
# Services: 60min Full Body Oriental Massage $58, 90min Full Body Oriental Massage $85
# Opening Hours: 9.00am to 10.30pm
# Contact: 65 6225 3231
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6591121766
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'object-fit:cover;width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Ann Healthcare 221 Balestier Road
# Date: 14/08/2023
# DateTime published: 2023-08-14T11:23:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Ann Healthcare 221 Balestier Road
# Location: 221 Balestier Road Singapore 329928
# Services: Our therapists are both friendly and highly skilled, with years of experience providing expert services. Prostate Massage acupressure points around the groin can promote better blood flow to your body, benefiting your overall health., 60mins Bodycare $60, 90mins Bodycare $90, 120mins Bodycare $120, 60mins Prostate Massage $150, Painless hair removal Price Range $50 – $350, We’re Hiring. Join Our Team
# Opening Hours: 9.30am to 10.30pm
# Contact: 65 8740 4888
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6587404888
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Yue Yuan Spa 805 North Bridge Road
# Date: 12/08/2023
# DateTime published: 2023-08-12T10:20:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Yue Yuan Spa 805 North Bridge Road
# Location: 805 North Bridge Road Singapore 198773
# Services: Each of our therapists have years of experience., 60mins Body Massage $60, 90mins Body Massage $90, 120mins Body Massage $120, We’re Hiring. Join Our Team
# Opening Hours: 7.00am to 10.30pm
# Contact: +65 6298 2326
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6582834576
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 623 Balestier Road
# Date: 11/08/2023
# DateTime published: 2023-08-11T15:55:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20400'%3E%3C/svg%3E (500 x 400)
# Spa Name: Bliss Paradise 623 Balestier Road
# Location: 623 Balestier Road Singapore 329914
# Services: 60mins Full Body Massage $60, 90mins Full Body Massage $90
# Opening Hours: 10.30am to 1.00am
# Contact: 65 8188 1252
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581881252
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Palace Spa 116 Middle Road
# Date: 08/08/2023
# DateTime published: 2023-08-08T09:44:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Palace Spa 116 Middle Road
# Location:  Enterprise House Singapore 188972
# Services: 60mins Chinese Massage $55, 90mins Chinese Massage $82, #02-01, ICB, Operating Hours: 8.30am to 10.30pm, We’re Hiring. Join Our Team
# Opening Hours: 8.30am to 10.30pm
# Contact: 65 6970 2729
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6588762722
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 7 Tanjong Pagar Plaza
# Date: 06/08/2023
# DateTime published: 2023-08-06T09:19:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Spa Name: Bliss Paradise 7 Tanjong Pagar Plaza
# Location: Singapore 081007
# Services: 60mins Body Therapy $60, 90mins Body Therapy $90, Blk     #02-108
# Opening Hours: 11.00am to 1.00am
# Contact: 65 8188 1252
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581881252
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Nature Spa 126 Owen Road
# Date: 05/08/2023
# DateTime published: 2023-08-05T08:05:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Nature Spa 126 Owen Road
# Location: 126 Owen Road #01-01 Singapore 218930
# Services: 60mins Thai & Oil Full Body Massage $68, 90mins Thai & Oil Full Body Massage $98
# Opening Hours: 10.00am to 10.30pm
# Contact: 65 6908 2738
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6590399878
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Yi He Tang 134 Rangoon Road
# Date: 04/08/2023
# DateTime published: 2023-08-04T17:24:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Yi He Tang 134 Rangoon Road
# Location: 134 Rangoon Road Singapore 218412
# Services: Our highly skilled therapists are trained in the art of TCM massage, ensuring an authentic and effective treatment., 60mins Chinese therapy $68, 90mins Chinese therapy $98
# Opening Hours: 9.00am to 10.30pm
# Contact: +65 8556 9488
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6585459319
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 205 Syed Alwi Road
# Date: 02/08/2023
# DateTime published: 2023-08-02T09:34:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Bliss Paradise 205 Syed Alwi Road
# Location: 205 Syed Alwi Road, Singapore 207737
# Services: Find Total Relaxation at, 60mins Full Body Massage $60, 90mins Full Body Massage $90
# Opening Hours: 12.00am to 3.00am
# Contact: 65 8188 1252
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581881252
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Xuan Spa 438 Race Course Road
# Date: 29/07/2023
# DateTime published: 2023-07-29T11:41:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Xuan Spa 438 Race Course Road
# Location: Singapore 218684
# Services: Promo price is only applicable between 9:30am-2pm daily, 60mins Hot Oil full body Massage $58, 90mins Hot Oil full body Massage $86, 90mins Hot Oil full body Massage $108,
# Opening Hours: 9.30am to 10.30pm
# Contact: +65 6294 9948
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6597793468
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Mu Wellness 332 Balestier Road
# Date: 24/07/2023
# DateTime published: 2023-07-24T20:09:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Mu Wellness 332 Balestier Road
# Location: 332 Balestier Road Singapore 329764
# Services: 60min Full Body Massage $58, 90min Full Body Massage $80
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 9087 3182
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6590873182
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Hito Iki Spa BlK 35 Telok Blangah Rise
# Date: 19/07/2023
# DateTime published: 2023-07-19T09:59:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Hito Iki Spa BlK 35 Telok Blangah Rise
# Location: Singapore 090035
# Services: 60mins Full Body Massage TCM $60, 90mins Full Body Massage TCM $90, BIK     #01-277, We’re Hiring. Join Our Team
# Opening Hours: 9.00am to 10.30pm
# Contact: 65 6518 3558
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6596422301
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Yi Ren Fang 67A Queen Street
# Date: 18/07/2023
# DateTime published: 2023-07-18T19:43:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Yi Ren Fang 67A Queen Street
# Location: Singapore 188546
# Services: Each of our therapists have years of experience in massage therapy., 60mins Full Body Oli Massage $60, 90mins Full Body Oli Massage $80, 2nd Floor
# Opening Hours: 9.30am to 10.30pm
# Contact: +65 6966 1360
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6588590954
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Yi Kang TCM Ang Mo Kio Ave 6
# Date: 16/07/2023
# DateTime published: 2023-07-16T21:44:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Yi Kang TCM Ang Mo Kio Ave 6
# Location: Singapore 560715
# Services: 60min Body therapy $60, 90min Body therapy $90, 60min Tendon prostate therapy + Oli $80, Blk 715      #01-4004
# Opening Hours: 10.30am to 10.30am
# Contact: 65 6983 7988
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6587384227
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: E Spa Ang Mo Kio Ave 1
# Date: 16/07/2023
# DateTime published: 2023-07-16T20:43:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: E Spa Ang Mo Kio Ave 1
# Location: Singapore 563226
# Services: Expert Massage Services by Our Caring Therapists, 60mins Full Body Oil Massage $58, 90mins Full Body Oil Massage $85, 60mins Japaness Bubble Massage $98, Blk 226C     ＃01-651
# Opening Hours: 8.30am to 10.30pm
# Contact: 65 6266 6606
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6581293933
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: The Mandarin in Wellness Ang Mo Kio Ave 5
# Date: 13/07/2023
# DateTime published: 2023-07-13T11:09:30+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: The Mandarin in Wellness Ang Mo Kio Ave 5
# Location: Singapore 560151
# Services: Experience Skilled Massage Therapy by Certified Therapist Miya for Muscle Tension Relief., 60mins Hot Oil Full Body Massage $68, 90mins Hot Oil Full Body Massage $102, Blk 151    , #01-3034,
# Opening Hours: Not available
# Contact: +65 8398 7190
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6583987190
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': ''}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: BaiHe Spa Bishan Street 11
# Date: 05/04/2023
# DateTime published: 2023-04-05T01:36:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: BaiHe Spa Bishan Street 11
# Location: Singapore 570152
# Services: 60mins Full Body Massage $58, 90mins Full Body Massage $86, 152  , #01-221
# Opening Hours: 9.30am to 10.30pm
# Contact: 65 6258 9897
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: 6562589897
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': ''}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Deluxe Spa Block 36 Beo Crescent
# Date: 01/03/2023
# DateTime published: 2023-03-01T15:18:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Deluxe Spa Block 36 Beo Crescent
# Location: Singapore 160036
# Services: All our therapist are all certified with accredited wellness certification and trained professionally ease muscle tensions and soothing massage therapy, 60mins Swedish Massage $58, #01-49
# Opening Hours: Not available
# Contact: +65 9460 5280
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6594605280
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': ''}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Fu Zu Wellness Blk 125 Lorong 1 Toa Payoh
# Date: 20/02/2023
# DateTime published: 2023-02-20T20:24:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Fu Zu Wellness Blk 125 Lorong 1 Toa Payoh
# Location: Singapore 310125
# Services: 60min Full Body Massage $58, 90min Full Body Massage $85, #01-543
# Opening Hours: 9.30am to 10.30pm
# Contact: +65 6677 7636
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6589311378
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Spa D Raviver 11 Jalan Bukit Merah
# Date: 19/02/2023
# DateTime published: 2023-02-19T18:23:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Spa D Raviver 11 Jalan Bukit Merah
# Location: 11 Jalan Bukit Merah, Singapore 150011
# Services: 60min Full Body Massage $55, 90min Full Body Massage $85
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 6278 9628
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6598432902
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Foreveryouspa 234 River Valley Road
# Date: 14/02/2023
# DateTime published: 2023-02-14T11:03:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Foreveryouspa 234 River Valley Road
# Location: 234 River Valley Road, Singapore 238292.
# Services: Our professional, experienced massage Spa therapists are waiting to serve you in our spa., 60mins Body Massage $60, 90mins Body Massage $88, Operating Hours: 10.00am to 10.30pm
# Opening Hours: 10.00am to 10.30pm
# Contact: +65 6235 5308
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: ParkView Thai Wellness Spa Alexandra Central Mall
# Date: 09/02/2023
# DateTime published: 2023-02-09T06:08:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: ParkView Thai Wellness Spa Alexandra Central Mall
# Location:  #03-10 Singapore 159971
# Services: We offer a range of soothing, deeply relaxing tension busting massages which focus on areas of the body that often suffer most from stress., 45mins Oil Massage $50, 60mins Oil Massage $58, 90mins Oil Massage $88, 321  Road,
# Opening Hours: Not available
# Contact: +65 8316 8559
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6583168559
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Orient TCM Beauty 574 Ang Mo Kio
# Date: 11/01/2023
# DateTime published: 2023-01-11T12:56:37+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Orient TCM Beauty 574 Ang Mo Kio
# Location: Singapore 560574
# Services: 60min  Full Body Massage $89, 90min  Full Body Massage $119, 90min  Full Body Massage $148, Ave 10,#01-1839
# Opening Hours: 8.00am to 10.30pm
# Contact: +65 6539 9973
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Foot King Spa 531 Upper Cross Street
# Date: 15/12/2022
# DateTime published: 2022-12-15T07:24:26+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Foot King Spa 531 Upper Cross Street
# Location: Hong Lim Complex Singapore 050531
# Services: Professional therapists always offer service tailored to your health condition. we care more than provide the best Massage service., 60min  Reflexology $39, 60min Body Massage $55, #01-02
# Opening Hours: 10.30am to 10.30pm
# Contact: +65 8175 8465
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Nature Healing 177 Toa Payoh Central
# Date: 29/09/2022
# DateTime published: 2022-09-29T15:54:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Spa Name: Nature Healing 177 Toa Payoh Central
# Location: Singapore 310177
# Services: We focus on TCM Tuina, Guasha & Cupping. TCM Tuina can stimulate acupoints and help muscle to overall muscle to improve blood circulation and whole body health., 60mins Full Body Massage $68, 60mins Foot Massage $45, #01-152, Operating Hours: 10.00am to 10.30pm
# Opening Hours: 10.00am to 10.30pm
# Contact: 65 6814 8866
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background', 'style': 'border-radius:10px'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Phoenix TCM 52 Telok Blangah Road
# Date: 27/08/2022
# DateTime published: 2022-08-27T06:28:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Spa Name: Phoenix TCM 52 Telok Blangah Road
# Location: Singapore 098829
# Services: 60mins Swedish Massage $60, 90mins Hot Oil Massage $128, 60mins Yoga Stretching Massage $89, Rd, House #01-01,
# Opening Hours: 10.00am to 10.30pm
# Contact: +65 6530 3839
# Contact Format: {'classes': 'wp-block-button__link has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px;color:#fffffa'}
# WhatsApp Contact: 6584385168
# WhatsApp Format: {'classes': 'wp-image-6080', 'style': 'width:225px;height:78px'}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: LQ Foot Therapy Spa 41 Holland Drive
# Date: 01/05/2022
# DateTime published: 2022-05-01T09:27:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Spa Name: LQ Foot Therapy Spa 41 Holland Drive
# Location: 41 Holland Drive #01-25 Singapore 270041
# Services: We have rich experience in full body massage and  reflexology., by G1298.com, The Massage Directory, Promotion (before 4pm Monday – Friday), 30mins  Massage $22, 30mins Body Massage $28
# Opening Hours: Not available
# Contact: 65 6970 5177
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background', 'style': 'border-radius:10px'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Palace Therapy 25 Club Street
# Date: 02/04/2022
# DateTime published: 2022-04-02T15:07:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Spa Name: Palace Therapy 25 Club Street
# Location: 25 Club Street Singapore 069412
# Services: Treat them to a therapeutic session that recharges their soul and body,, book a session with us today!, 60mins Oriental Body Massage $68 Before 8pm
# Opening Hours: 10.00am to 10.30pm
# Contact: 65 6767 6466
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background wp-element-button', 'style': 'border-radius:10px'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------
# url: https://g1298.com/category/central-area/
# Spa Name: Mango Spa 3 Greendale Avenue
# Date: 01/03/2022
# DateTime published: 2022-03-01T11:58:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Spa Name: Mango Spa 3 Greendale Avenue
# Location: 3 Greendale Ave, Singapore 289498
# Services: Tucked away in a cozy nook off Bukit Timah Roa­­­d, surrounded by lush greenery in the quaint Greenwood dining enclave, our team of hand-picked therapists and friendly store manager strive to create an immensely relaxing and pampering  experience, specially curated to your tastes.​ We look forward to seeing you soon! Sincerely,, 60mins Body Massage $65, 90mins Deep tissue massage $98, 90mins Hot stones massage $146, Operating Hours: 9.00am to 10.30pm
# Opening Hours: 9.00am to 10.30pm
# Contact: +65 6835 0038
# Contact Format: {'classes': 'wp-block-button__link has-white-color has-vivid-green-cyan-background-color has-text-color has-background', 'style': 'border-radius:10px'}
# WhatsApp Contact: Not available
# WhatsApp Format: {'classes': '', 'style': ''}
# ------------------------------------------------------

# %%
import re
import requests
from bs4 import BeautifulSoup

# Function to clean the services description
def clean_services(service_description, opening_hours):
    if opening_hours:
        return service_description.replace(opening_hours, '').strip()
    return service_description

# URL of the page to scrape
url = 'https://g1298.com/category/central-area/'

try:
    # Send a request to the website
    response = requests.get(url)
    response.raise_for_status()

    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all articles in the Central Area category
    articles = soup.find_all('article', class_='category-central-area')

    for article in articles:
        try:
            spa_name = article.find('h2', class_='entry-title').get_text()
            time_element = article.find('time', class_='entry-date')
            date, datetime = time_element.get_text(), time_element['datetime']

            # Image extraction
            shop_image_tag = article.find('div', class_='post-thumbnail').find('img')
            shop_image_src, shop_image_width, shop_image_height = shop_image_tag['src'], shop_image_tag['width'], shop_image_tag['height']

            # Staff information extraction
            staff_images = article.find_all('figure', class_='wp-block-image')
            staff_info = [{'source': img.find('img')['src'], 'width': img.find('img')['width'], 'height': img.find('img')['height']} for img in staff_images]

            description = article.find('h2', class_='wp-block-heading').get_text()
            service_description = article.find('p', class_='has-text-align-center').get_text()
            opening_hours_match = re.search(r'Opening Hours\s*(\d{1,2}\.\d{2}am\s+to\s+\d{1,2}\.\d{2}(?:am|pm))', service_description, re.IGNORECASE)
            opening_hours = opening_hours_match.group() if opening_hours_match else "Not available"
            service_description = clean_services(service_description, opening_hours)

            # Contact information extraction
            contact_tag = article.find('a', href=re.compile(r'^tel:'))
            contact = contact_tag['href'][4:] if contact_tag else "Not available"

            # WhatsApp information extraction
            whatsapp_image = article.find('img', alt=True, src=True)
            whatsapp_link = whatsapp_image['src'] if whatsapp_image else None

            # Output the extracted information
            print(f"URL: {url}")
            print(f"Spa Name: {spa_name}")
            print(f"Date: {date}")
            print(f"DateTime Published: {datetime}")
            print(f"Shop Image: {shop_image_src} ({shop_image_width} x {shop_image_height})")
            print(f"Description: {description}")
            print(f"Services: {service_description}")
            print(f"Opening Hours: {opening_hours}")
            print(f"Contact: {contact}")
            print(f"WhatsApp Link: {whatsapp_link}")
            print("------------------------------------------------------")

        except Exception as e:
            print(f"An error occurred while processing an article: {e}")

except requests.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"An error occurred: {err}")
# Out:
# URL: https://g1298.com/category/central-area/
# Spa Name: Seasons Wellness Spa 43 Beach Road
# Date: 20/11/2023
# DateTime Published: 2023-11-20T12:46:19+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Seasons Wellness Spa located in 43 Beach Road By G1298.com – The Massage Directory
# Services: Massages to Restore the Harmony in Your Body.60min Body Massage $6890min Body Massage $98120min Body Massage $11643 Beach Road Singapore 189681
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: +65 6336 8105
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Ichiban The Spa 9 Selegie Road
# Date: 19/11/2023
# DateTime Published: 2023-11-19T15:39:57+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Best Massage Spa in Singapore Ichiban The Spa located in 9 Selegie Road By G1298.com – The Massage Directory
# Services: 60min Swedish Massage $8460min Hot Oil Massage $8490min Swedish Massage $1269 Selegie Road, #01-31 Selegie House,Singapore 180009
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: 65 6333 3344
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: YuQuan Spa 288 Jalan Besar
# Date: 14/11/2023
# DateTime Published: 2023-11-14T16:14:41+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: YuQuan Spa at Jalan Besar by G1298.com – The Massage Directory
# Services: 40mins Swedish Full Body Care $5060mins Chinese Therapy / Tuina $6090mins Chinese Therapy Full Body $88288 Jalan Besar #01-01 Feng Ming Building Singapore 208951
# Opening Hours: Opening Hours 10.00am to 2.00am
# Contact: 65 6539 9858
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Cuppage Wellness 5 Koek Road
# Date: 13/10/2023
# DateTime Published: 2023-10-13T10:11:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Expert Massage Services for Pain Relief and Relaxation Cuppage Wellness By G1298.com – The Massage Directory
# Services: 60min Full Body Massage $5860min Hot Oil Full Body Massage $6860min Korean Bubble Foam Massage $865 Koek Road #B1-02 Cupppage Plaza Singapore 228796Operating Hours: 10.30am to 11.00pm
# Opening Hours: Not available
# Contact: +65 8267 5689
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: SPA M Blk 8 Telok Blangah Crescent
# Date: 30/08/2023
# DateTime Published: 2023-08-30T13:20:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Find Inner Peace and Relaxation with Our Massage and Spa Treatments Spa M located in Telok BIangah Crescent by G1298.com – The Massage Directory
# Services: 60mins Deep Tissue Massage $5890mins Deep Tissue Massage $88120mins Deep Tissue Massage $118Blk 8 Telok BIangah Crescent #01-157 Singapore 090008
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: +65 6980 8479
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Soul Wellness Spa 41 Holland Drive
# Date: 29/08/2023
# DateTime Published: 2023-08-29T11:26:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20299'%3E%3C/svg%3E (500 x 299)
# Description: Soul Wellness Spa today Conveniently located in the heart of Holland G1298.com – The Massage Directory
# Services: We provide the best customer service to our clients in our beloved Hoboken. Ample parking lots right behind our spa. 60mins Full Body Massage $8990mins Full Body Massage $12941 holland drive Singapore 270041Opening Hours: 9.00am to 10.30pm
# Opening Hours: Not available
# Contact: +65 6493 2656
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20299'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Sgyogamassage 333 Beach Road
# Date: 27/08/2023
# DateTime Published: 2023-08-27T09:33:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Description: Sgyogamassage located in 333 Beach Road experience the traditional Chinese Full body Therapy.
# Services: Tuina is a hands-on body massage treatment that uses Chinese Medicine (TCM) principles60mins TCM Therapy / Tuina $58 90minsTCM Therapy / Tuina  $88333 Beach Road Singapore 199563
# Opening Hours: Opening Hours 10.30am to 10.30pm
# Contact: +65 6518 3305
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 14 Kim Keat lane
# Date: 24/08/2023
# DateTime Published: 2023-08-24T10:34:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Description: Get the Ultimate Massage Experience at Bliss Paradise 14 Kim Keat Lane
# Services: 60mins Full Body Massage $6090mins Full Body Massage $9014 Kim Keat Lane Singapore 328872
# Opening Hours: Opening Hours 10.00am to 1.00am
# Contact: 65 6539 9858
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: TL Beauty Wellness 220 Orchard Road
# Date: 22/08/2023
# DateTime Published: 2023-08-22T20:01:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: G1298.com – Your Premier Choice for Expert Massage Services TL Beauty Wellness located in Midpoint Orchard
# Services: 60min Full Body Massage $5860min Hot Oil Full Body Massage $6860min Korean Bubble Foam Massage $86220 Orchard Rd, #02-06 Midpoint Orchard, Singapore 238852Operating Hours: 10.30am to 10.30pm
# Opening Hours: Not available
# Contact: +65 8334 8801
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Almond Spa 150 South Bridge Road
# Date: 20/08/2023
# DateTime Published: 2023-08-20T09:03:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Best Massage Spa in Singapore Almond Spa located in South Bridge Road by G1298.com – The Massage Directory
# Services: 60mins Chinese Massage $5890mins Chinese Massage $86120mins Chinese Massage $108150 South Bridge Road, 01-18, Fook Hai Building Singapore 058727We’re Hiring. Join Our Team
# Opening Hours: Opening Hours 10.00am to 10.30pm
# Contact: 65 6015 0769
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Wan Jia Wellness 279 Outram Road
# Date: 19/08/2023
# DateTime Published: 2023-08-19T23:01:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Wan Jia Wellness: Experts in Stress Reduction and Pain Management By G1298.com – The Massage Directory
# Services: Each of our therapists have years of experience in massage therapy.60mins Chinese Massage $6090mins Chinese Massage $88279 Outram Road, #01-01 Outram Loft, Singapore 169066We’re Hiring. Join Our Team
# Opening Hours: Opening Hours 10.30am to 10.30pm
# Contact: +65 6993 7853
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 86 Circuit Road
# Date: 17/08/2023
# DateTime Published: 2023-08-17T13:45:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Get the Ultimate Body Massage Experience at Bliss Paradise 86 Circuit Road By G1298.com – The Massage Directory
# Services: 60mins Full Body Massage $6090mins Full Body Massage $9086 Circuit Road #01-995 Singapore 370086
# Opening Hours: Opening Hours 10.30am to 1.00am
# Contact: 65 8188 1252
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Liu Xin Yu wellness & Spa 78 Guan Chuan Street
# Date: 16/08/2023
# DateTime Published: 2023-08-16T11:00:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Liu Xin Yu Start your day feeling relaxed with our Happy hour promotion!
# Services: 9.00 am to 1.00pm60min Full Body Oriental Massage $5890min Full Body Oriental Massage $87BLK 78 Guan Chuan Street 01-45 Singapore 160078
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: 65 6525 9468
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Li Xin Beauty Wellness 30 Sago Street
# Date: 16/08/2023
# DateTime Published: 2023-08-16T06:50:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Art of Massage Li Xin Beauty Wellness located in 30 Sago Street By G1298.com – The Massage Directory
# Services: 60min Full Body Oriental Massage $5890min Full Body Oriental Massage $8530 Sago Street, Singapore 059024
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: 65 6225 3231
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Ann Healthcare 221 Balestier Road
# Date: 14/08/2023
# DateTime Published: 2023-08-14T11:23:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Ann Healthcare Centre located in Balestier Road Spa
# Services: Our therapists are both friendly and highly skilled, with years of experience providing expert services. Prostate Massage acupressure points around the groin can promote better blood flow to your body, benefiting your overall health.60mins Bodycare $6090mins Bodycare $90120mins Bodycare $120 60mins Prostate Massage $150Painless hair removal Price Range $50 – $350221 Balestier Road Singapore 329928We’re Hiring. Join Our Team
# Opening Hours: Opening Hours 9.30am to 10.30pm
# Contact: 65 8740 4888
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Yue Yuan Spa 805 North Bridge Road
# Date: 12/08/2023
# DateTime Published: 2023-08-12T10:20:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Relax and Rejuvenate with our Expert Massage Services Yue Yuan Spa located in North Bridge Road.
# Services: Each of our therapists have years of experience.60mins Body Massage $6090mins Body Massage $90120mins Body Massage $120805 North Bridge Road Singapore 198773We’re Hiring. Join Our Team
# Opening Hours: Opening Hours 7.00am to 10.30pm
# Contact: +65 6298 2326
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 623 Balestier Road
# Date: 11/08/2023
# DateTime Published: 2023-08-11T15:55:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20400'%3E%3C/svg%3E (500 x 400)
# Description: Experience Lasting Relief with Bliss Paradise 623 Balestier Road Your Go-To for Massage Therapy Near You
# Services: 60mins Full Body Massage $6090mins Full Body Massage $90623 Balestier Road Singapore 329914
# Opening Hours: Opening Hours 10.30am to 1.00am
# Contact: 65 8188 1252
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20400'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Palace Spa 116 Middle Road
# Date: 08/08/2023
# DateTime Published: 2023-08-08T09:44:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Relax and Rejuvenate with Affordable Massage Services at Palace Spa, Bugis – $48/Hour
# Services: 60mins Chinese Massage $5590mins Chinese Massage $82116 Middle Road #02-01, ICB Enterprise House Singapore 188972Operating Hours: 8.30am to 10.30pmWe’re Hiring. Join Our Team
# Opening Hours: Not available
# Contact: 65 6970 2729
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 7 Tanjong Pagar Plaza
# Date: 06/08/2023
# DateTime Published: 2023-08-06T09:19:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E (400 x 300)
# Description: Unlocking the Healing Power of TCM Massage Effective Techniques and Benefits at Bliss Paradise 7 Tanjong Pagar Plaza
# Services: 60mins Body Therapy $6090mins Body Therapy $90Blk 7 Tanjong Pagar Plaza #02-108 Singapore 081007
# Opening Hours: Opening Hours 11.00am to 1.00am
# Contact: 65 8188 1252
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20400%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Nature Spa 126 Owen Road
# Date: 05/08/2023
# DateTime Published: 2023-08-05T08:05:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Discover Pure Relaxation Thai Massage Near Me at Nature Spa Owen Road
# Services: 60mins Thai & Oil Full Body Massage $6890mins Thai & Oil Full Body Massage $98126 Owen Road #01-01 Singapore 218930
# Opening Hours: Opening Hours 10.00am to 10.30pm
# Contact: 65 6908 2738
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Yi He Tang 134 Rangoon Road
# Date: 04/08/2023
# DateTime Published: 2023-08-04T17:24:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: 益和堂 TCM Massage Near Me at Yi He Tang – Experience Traditional Healing By G1298.com – The Massage Directory
# Services: Our highly skilled therapists are trained in the art of TCM massage, ensuring an authentic and effective treatment.60mins Chinese therapy $6890mins Chinese therapy $98134 Rangoon Road Singapore 218412
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: +65 8556 9488
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Bliss Paradise 205 Syed Alwi Road
# Date: 02/08/2023
# DateTime Published: 2023-08-02T09:34:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Bliss Paradise 205 Syed Alwi Road
# Services: Find Total Relaxation at Bliss ParadiseSingapore’s Best Massage for Stress and Tension Relief60mins Full Body Massage $6090mins Full Body Massage $90205 Syed Alwi Road, Singapore 207737
# Opening Hours: Opening Hours 12.00am to 3.00am
# Contact: 65 8188 1252
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Xuan Spa 438 Race Course Road
# Date: 29/07/2023
# DateTime Published: 2023-07-29T11:41:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Xuan Spa located in 438 Race Course Road – Experience the Benefits of Massage Therapy for Relaxation and Healing
# Services: Promo price is only applicable between 9:30am-2pm daily60mins Hot Oil full body Massage $5890mins Hot Oil full body Massage $8690mins Hot Oil full body Massage $108438 Race Course Road Singapore 218684
# Opening Hours: Opening Hours 9.30am to 10.30pm
# Contact: +65 6294 9948
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Mu Wellness 332 Balestier Road
# Date: 24/07/2023
# DateTime Published: 2023-07-24T20:09:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Unwind and Rejuvenate with Aromatherapy Massage at MU WELLNESS by G1298.com – The Massage Directory
# Services: 60min Full Body Massage $5890min Full Body Massage $80332 Balestier Road Singapore 329764
# Opening Hours: Opening Hours 10.30am to 10.30pm
# Contact: +65 9087 3182
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Hito Iki Spa BlK 35 Telok Blangah Rise
# Date: 19/07/2023
# DateTime Published: 2023-07-19T09:59:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Best Massage and Spa Services at Hito Iki Spa located in Telok Blangah Rise By G1298.com – The Massage Directory
# Services: 60mins Full Body Massage TCM $6090mins Full Body Massage TCM $90BIK 35 Telok Blangah Rise #01-277 Singapore 090035We’re Hiring. Join Our Team
# Opening Hours: Opening Hours 9.00am to 10.30pm
# Contact: 65 6518 3558
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Yi Ren Fang 67A Queen Street
# Date: 18/07/2023
# DateTime Published: 2023-07-18T19:43:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Yi Ren Fang located in Queen Street Experts in Stress Reduction and Pain Management by G1298.com – The Massage Directory
# Services: Each of our therapists have years of experience in massage therapy.60mins Full Body Oli Massage $6090mins Full Body Oli Massage $8067A Queen Street 2nd Floor Singapore 188546
# Opening Hours: Opening Hours 9.30am to 10.30pm
# Contact: +65 6966 1360
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Yi Kang TCM Ang Mo Kio Ave 6
# Date: 16/07/2023
# DateTime Published: 2023-07-16T21:44:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Yi Kang TCM & Therapy Center located in Mo Kio Ave 6 – Your Source for Pain Relief
# Services: 60min Body therapy $6090min Body therapy $9060min Tendon prostate therapy + Oli $80Blk 715 Ang Mo Kio Ave 6 #01-4004Singapore 560715
# Opening Hours: Opening Hours 10.30am to 10.30am
# Contact: 65 6983 7988
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: E Spa Ang Mo Kio Ave 1
# Date: 16/07/2023
# DateTime Published: 2023-07-16T20:43:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Pampering Bliss Awaits at E Spa located in Ang Mo Kio Ave 1 By G1298.com – The Massage Directory
# Services: Expert Massage Services by Our Caring Therapists60mins Full Body Oil Massage $5890mins Full Body Oil Massage $8560mins Japaness Bubble Massage $98Blk 226C Ang Mo Kio Ave 1＃01-651 Singapore 563226
# Opening Hours: Opening Hours 8.30am to 10.30pm
# Contact: 65 6266 6606
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: The Mandarin in Wellness Ang Mo Kio Ave 5
# Date: 13/07/2023
# DateTime Published: 2023-07-13T11:09:30+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Unlock Wellness The Power of The Mandarin in Wellness for Vibrant Living
# Services: Experience Skilled Massage Therapy by Certified Therapist Miya for Muscle Tension Relief.60mins Hot Oil Full Body Massage $6890mins Hot Oil Full Body Massage $102Blk 151 Ang Mo Kio Ave 5, #01-3034, Singapore 560151Opening Hours 10.30.am to 10.30pm
# Opening Hours: Not available
# Contact: +65 8398 7190
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: BaiHe Spa Bishan Street 11
# Date: 05/04/2023
# DateTime Published: 2023-04-05T01:36:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: BaiHe Spa Experienced therapists who are dedicated to providing personalized care and exceptional service.
# Services: 60mins Full Body Massage $5890mins Full Body Massage $86152 Bishan Street 11, #01-221 Singapore 570152
# Opening Hours: Opening Hours 9.30am to 10.30pm
# Contact: 65 6258 9897
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Deluxe Spa Block 36 Beo Crescent
# Date: 01/03/2023
# DateTime Published: 2023-03-01T15:18:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Welcome to Best Deluxe Spa relax your muscles
# Services: All our therapist are all certified with accredited wellness certification and trained professionally ease muscle tensions and soothing massage therapy60mins Swedish Massage $58Block 36 Beo Crescent #01-49 Singapore 160036Opening Hours 10.30.am to 10.30pm
# Opening Hours: Not available
# Contact: +65 9460 5280
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Fu Zu Wellness Blk 125 Lorong 1 Toa Payoh
# Date: 20/02/2023
# DateTime Published: 2023-02-20T20:24:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the Benefits of Massage at Fu Zu Wellness By G1298.com – The Massage Directory
# Services: 60min Full Body Massage $5890min Full Body Massage $85Blk 125 Lorong 1 Toa Payoh #01-543Singapore 310125
# Opening Hours: Opening Hours 9.30am to 10.30pm
# Contact: +65 6677 7636
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Spa D Raviver 11 Jalan Bukit Merah
# Date: 19/02/2023
# DateTime Published: 2023-02-19T18:23:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Spa D Raviver located in Jalan Bukit Merah – Nurturing Mind, Body, and Soul with Care
# Services: 60min Full Body Massage $5590min Full Body Massage $8511 Jalan Bukit Merah, Singapore 150011
# Opening Hours: Opening Hours 10.30am to 10.30pm
# Contact: +65 6278 9628
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Foreveryouspa 234 River Valley Road
# Date: 14/02/2023
# DateTime Published: 2023-02-14T11:03:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: At Foreveryouspa, Our Skilled Massage Therapists Deliver Exceptional Customer Service for Spa Massages
# Services: Our professional, experienced massage Spa therapists are waiting to serve you in our spa.60mins Body Massage $6090mins Body Massage $88234 River Valley Road, Singapore 238292.Operating Hours: 10.00am to 10.30pm
# Opening Hours: Not available
# Contact: +65 6235 5308
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: ParkView Thai Wellness Spa Alexandra Central Mall
# Date: 09/02/2023
# DateTime Published: 2023-02-09T06:08:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: ParkView Thai Wellness Spa Traditional Thai massage. by G1298.com – The Massage Directory
# Services: We offer a range of soothing, deeply relaxing tension busting massages which focus on areas of the body that often suffer most from stress.45mins Oil Massage $5060mins Oil Massage $5890mins Oil Massage $88321 Alexandra Road, Alexandra central #03-10 Singapore 159971Opening Hours 10am to 10.30pm
# Opening Hours: Not available
# Contact: +65 8316 8559
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Orient TCM Beauty 574 Ang Mo Kio
# Date: 11/01/2023
# DateTime Published: 2023-01-11T12:56:37+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Relieve Pain with Expert TCM Treatment at Orient TCM Beauty – Acupuncture, Cupping, Moxibustion, Tuina and more
# Services: 60min TCM Full Body Massage $8990min TCM Full Body Massage $11990min TCM Full Body Massage $148574 Ang Mo Kio Ave 10,#01-1839 Singapore 560574
# Opening Hours: Opening Hours 8.00am to 10.30pm
# Contact: +65 6539 9973
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Foot King Spa 531 Upper Cross Street
# Date: 15/12/2022
# DateTime Published: 2022-12-15T07:24:26+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Foot King Spa has everything you expect for a genuine comfort.
# Services: Professional therapists always offer service tailored to your health condition. we care more than provide the best Massage service. 60min Foot Reflexology $3960min Body Massage $55531 Upper Cross Street #01-02 Hong Lim Complex Singapore 050531
# Opening Hours: Opening Hours 10.30am to 10.30pm
# Contact: +65 8175 8465
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Nature Healing 177 Toa Payoh Central
# Date: 29/09/2022
# DateTime Published: 2022-09-29T15:54:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: Nature Healing we treat not just your symptoms, but also the root cause of your pain issues.
# Services: We focus on TCM Tuina, Guasha & Cupping. TCM Tuina can stimulate acupoints and help muscle to overall muscle to improve blood circulation and whole body health.60mins Full Body Massage $6860mins Foot Massage $45177 Toa Payoh Central #01-152 Singapore 310177Operating Hours: 10.00am to 10.30pm
# Opening Hours: Not available
# Contact: 65 6814 8866
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Phoenix TCM 52 Telok Blangah Road
# Date: 27/08/2022
# DateTime Published: 2022-08-27T06:28:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E (500 x 300)
# Description: Experience the healing power of Phoenix TCM located in Telok Blangah Road By G1298.com The Massage Directory
# Services: 60mins Swedish Massage $6090mins Hot Oil Massage $12860mins Yoga Stretching Massage $8952 Telok Blangah Rd, House #01-01, Singapore 098829
# Opening Hours: Opening Hours 10.00am to 10.30pm
# Contact: +65 6530 3839
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20500%20300'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: LQ Foot Therapy Spa 41 Holland Drive
# Date: 01/05/2022
# DateTime Published: 2022-05-01T09:27:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: LQ Foot Therapy Spa Unisex massage conveniently located near Holland Village that offers treatments to de-stress and unwind both your body and your mind.
# Services: We have rich experience in full body massage and foot reflexology. by G1298.com The Massage DirectoryPromotion (before 4pm Monday – Friday)30mins Foot Massage $2230mins Body Massage $28Opening Hours 10.00am to 1030pm41 Holland Drive #01-25 Singapore 270041
# Opening Hours: Not available
# Contact: 65 6970 5177
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Palace Therapy 25 Club Street
# Date: 02/04/2022
# DateTime Published: 2022-04-02T15:07:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: Palace Therapy Indulge Yourself in a Luxurious Oriental Boutique Spa Experience at Affordable Rates
# Services: Treat them to a therapeutic session that recharges their soul and body, book a session with us today! 60mins Oriental Body Massage $68 Before 8pm25 Club Street Singapore 069412
# Opening Hours: Opening Hours 10.00am to 10.30pm
# Contact: 65 6767 6466
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E
# ------------------------------------------------------
# URL: https://g1298.com/category/central-area/
# Spa Name: Mango Spa 3 Greendale Avenue
# Date: 01/03/2022
# DateTime Published: 2022-03-01T11:58:00+08:00
# Shop Image: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E (512 x 512)
# Description: The founding philosophy of Mango Spa is to provide an escape from the hustle and bustle of urban life in Singapore.
# Services: Tucked away in a cozy nook off Bukit Timah Roa­­­d, surrounded by lush greenery in the quaint Greenwood dining enclave, our team of hand-picked therapists and friendly store manager strive to create an immensely relaxing and pampering spa experience, specially curated to your tastes.​ We look forward to seeing you soon! Sincerely, Mango Spa60mins Body Massage $6590mins Deep tissue massage $9890mins Hot stones massage $1463 Greendale Ave, Singapore 289498Operating Hours: 9.00am to 10.30pm
# Opening Hours: Not available
# Contact: +65 6835 0038
# WhatsApp Link: data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20512%20512'%3E%3C/svg%3E
# ------------------------------------------------------
